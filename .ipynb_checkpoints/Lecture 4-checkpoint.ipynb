# %%
import twitter

CONSUMER_KEY='XXUQlJ3P6SLo5cMoACdHw'
CONSUMER_SECRET='lIHSK9YSF7XbUc0xIpGUxDIZlOuWUB9eh60VyPuuI'
OAUTH_TOKEN='98701585-MyvDH0qDynyLQXCcZ1WNgK1UoPUiDq302xffXf5dO'
OAUTH_TOKEN_SECRET='WcpBHlkOrrO440gQtagPn2g3HkiHSu3uDL8mj69sa8PHe'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET, CONSUMER_KEY, 
                           CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

print twitter_api

# %%
WORLD_WOE_ID=1
US_WOE_ID=23424977

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print world_trends
print
print us_trends
# Out:
# [{u'created_at': u'2014-01-30T03:12:55Z', u'trends': [{u'url': u'http://twitter.com/search?q=Lenovo', u'query': u'Lenovo', u'name': u'Lenovo', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23CovenSeasonFinale', u'query': u'%23CovenSeasonFinale', u'name': u'#CovenSeasonFinale', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23GusttavoLimaNoMultishow', u'query': u'%23GusttavoLimaNoMultishow', u'name': u'#GusttavoLimaNoMultishow', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23ElTraumaDeUnaMujer', u'query': u'%23ElTraumaDeUnaMujer', u'name': u'#ElTraumaDeUnaMujer', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23MOTAVATOUR', u'query': u'%23MOTAVATOUR', u'name': u'#MOTAVATOUR', u'promoted_content': None, u'events': None}, {u'url': u'http://twitter.com/search?q=%23ConfidentVideoTODAY', u'query': u'%23ConfidentVideoTODAY', u'name': u'#C
# ...

# %%
import json

print json.dumps(world_trends, indent=1)
print
print json.dumps(us_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2014-01-30T03:12:55Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=Lenovo",
#     "query": "Lenovo",
#     "name": "Lenovo",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CovenSeasonFinale",
#     "query": "%23CovenSeasonFinale",
#     "name": "#CovenSeasonFinale",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23GusttavoLimaNoMultishow",
#     "query": "%23GusttavoLimaNoMultishow",
#     "name": "#GusttavoLimaNoMultishow",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23ElTraumaDeUnaMujer",
#     "query": "%23ElTraumaDeUnaMujer",
#     "name": "#ElTraumaDeUnaMujer",
#     "promoted_content": null,
#     "events": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23MOTAVATOUR",
#     "query": "%23MOTAVATOUR",
# ...

# %%
world_trends_set = set([trend['name']
                        for trend in world_trends[0]['trends']])
us_trends_set = set([trend['name'] 
                     for trend in us_trends[0]['trends']])

common_trends = world_trends_set.intersection(us_trends_set)

print common_trends
# Out:
# set([u'#CovenSeasonFinale', u'#MOTAVATOUR', u'Cordelia'])

# %%
twitter_api.search.tweets?

# %%
search_results['search_metadata']
# Out:
# {u'completed_in': 0.024,
#  u'count': 100,
#  u'max_id': 428731936274939903,
#  u'max_id_str': u'428731936274939903',
#  u'query': u'%252540justinbieber',
#  u'refresh_url': u'?since_id=428731936274939903&q=%252540justinbieber&include_entities=1',
#  u'since_id': 0,
#  u'since_id_str': u'0'}

# %%
q='#bigdata'
count=100
search_results = twitter_api.search.tweets(q=q, count=count)
statuses = search_results['statuses']

for _ in range(1):
    print "Length of statuses list (number of statuses)", len(statuses)
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError, e:
        break
    
    kwargs=dict([kv.split('=') for kv in next_results[1:].split("&")])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']
    
    

print json.dumps(statuses[0], indent=1)
print len(statuses)
# Out:
# Length of statuses list (number of statuses) 100
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @SocialMediaLaw1: RT @JFBrashear: When #BigData Marketing Becomes Stalking. #privacy http://t.co/v5l8JPBHxO\u201d",
#  "in_reply_to_status_id": null,
#  "id": 428736921892691968,
#  "favorite_count": 0,
#  "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">HootSuite</a>",
#  "retweeted": false,
#  "coordinates": null,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 41905057,
#     "indices": [
#      3,
#      19
#     ],
#     "id_str": "41905057",
#     "screen_name": "SocialMediaLaw1",
#     "name": "Social Media Law"
#    },
#    {
#     "id": 18980319,
#     "indices": [
#      24,
#      35
#     ],
#     "id_str": "18980319",
#     "screen_name": "JFBrashear",
#     "name": "Jim Brashear"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      42,
#      50
#     ],
#     "text": "BigData"
#    },
#    {
# ...

# %%
print statuses[0]['id']
# Out:
# 428736921892691968

# %%
t = [ status 
      for status in statuses
          if status['id'] == 428736921892691968 ][0]

# Explore the variable t to get familiarized with the data structure...

print t['retweet_count']
print t['retweeted_status']
# Out:
# 1
# ...

# %%
db
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-274ddd5bb395> in <module>()
# ----> 1 db
#
# NameError: name 'db' is not defined

# %%
__author__ = 'mongolab'

# Written with pymongo-2.6 
# Documentation: http://api.mongodb.org/python/
# A python script connecting to a MongoDB given a MongoDB Connection URI.

import sys
import pymongo

### Create seed data

SEED_DATA = [
    {
        'decade': '1970s',
        'artist': 'Debby Boone',
        'song': 'You Light Up My Life',
        'weeksAtOne': 10
    },
    {
        'decade': '1980s',
        'artist': 'Olivia Newton-John',
        'song': 'Physical',
        'weeksAtOne': 10
    },
    {
        'decade': '1990s',
        'artist': 'Mariah Carey',
        'song': 'One Sweet Day',
        'weeksAtOne': 16
    }
]
MONGODB_URI = 'mongodb://elainec:lemonmania20@ds027829.mongolab.com:27829/gadb'


def main(args):
    client = pymongo.MongoClient(MONGODB_URI)
    db = client.get_default_database()
    
    songs = db['songs']
    songs.insert(SEED_DATA)
    query = {'song': 'One Sweet Day'}
    
    songs.update(query, {'$set': {'artist': 'Mariah Carey ft. Boyz II Men'}})
    
    cursor = songs.find({'weeksAtOne': {'$gte':10}}).sort('decade',1)
    
    for doc in cursor:
        print ('In the %s, %s by %s topped the charts for %d straight weeks.' %(doc['decade'], doc['song'], doc['artist'], doc['weeksAtOne']))
        
    db.drop_collection('songs')
    client.close()

if __name__ == '__main__':
    main(sys.argv[1:])
# Out:
# In the 1970s, You Light Up My Life by Debby Boone topped the charts for 10 straight weeks.
# In the 1980s, Physical by Olivia Newton-John topped the charts for 10 straight weeks.
# In the 1990s, One Sweet Day by Mariah Carey ft. Boyz II Men topped the charts for 16 straight weeks.

# %%
print search_results['statuses'][0]
# Out:
# {u'contributors': None, u'truncated': False, u'text': u'RT @MeghanMBiro: #TChat LOOK &gt; @ButtersRecruit: @KayleighNance use tools like #OpenWeb helps as it harnesses the #bigdata for you! Ask @shr\u2026', u'in_reply_to_status_id': None, u'id': 428726516852457472, u'favorite_count': 0, u'source': u'<a href="http://bufferapp.com" rel="nofollow">Buffer</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [{u'id': 22634164, u'indices': [3, 15], u'id_str': u'22634164', u'screen_name': u'MeghanMBiro', u'name': u'Meghan M. Biro'}, {u'id': 156692812, u'indices': [34, 49], u'id_str': u'156692812', u'screen_name': u'ButtersRecruit', u'name': u'Sara Fleischman'}, {u'id': 15344604, u'indices': [51, 65], u'id_str': u'15344604', u'screen_name': u'KayleighNance', u'name': u'KNance'}, {u'id': 9185562, u'indices': [138, 143], u'id_str': u'9185562', u'screen_name': u'shravangoli', u'name': u'shravan goli'}], u'hashtags': [{u'indices': [17, 23], u'text': u'
# ...

# %%
import sys
import pymongo

def blah(args):
    
    search_results = twitter_api.search.tweets(q=q, count=count)
    
    client = pymongo.MongoClient(MONGODB_URI)
    db = client.get_default_database()
    
    tweets=db['tweets']
    tweets.insert(search_results['statuses'])
    
    #query = {'retweet_count': {'$gte':0}}

    theone = tweets.find({'retweet_count': {'$gte':0}})[0]
    
    print theone

# %%
db.tweets.find_one?
# Out:
# Object `db.tweets.find_one` not found.

# %%
find_one()?
# Out:
#   File "<ipython-input-69-cd1191272bdf>", line 1
#     find_one()?
#               ^
# SyntaxError: invalid syntax

# %%
import sys
import pymongo

    
search_results = twitter_api.search.tweets(q=q, count=count)
    
client = pymongo.MongoClient(MONGODB_URI)
db = client.get_default_database()
    
tweets=db['tweets']
tweets.insert(search_results['statuses'])
    
query = {'retweet_count': {'$gte':0}}

theone = tweets.find(query)[0]
    
print theone
# Out:
# {u'contributors': None, u'truncated': False, u'text': u'Predictive Analytics Predictions For 2014  #BigData http://t.co/HzAGfiPMft', u'in_reply_to_status_id': None, u'id': 428749151548227584L, u'favorite_count': 0, u'source': u'<a href="http://tweetadder.com" rel="nofollow">TweetAdder v4</a>', u'retweeted': False, u'coordinates': None, u'entities': {u'symbols': [], u'user_mentions': [], u'hashtags': [{u'indices': [43, 51], u'text': u'BigData'}], u'urls': [{u'url': u'http://t.co/HzAGfiPMft', u'indices': [52, 74], u'expanded_url': u'http://www.bigdata-startups.com/predictive-analytics-predictions-2014/', u'display_url': u'bigdata-startups.com/predictive-ana\u2026'}]}, u'in_reply_to_screen_name': None, u'in_reply_to_user_id': None, u'retweet_count': 0, u'id_str': u'428749151548227584', u'favorited': False, u'user': {u'follow_request_sent': False, u'profile_use_background_image': True, u'id': 440736069, u'verified': False, u'profile_text_color': u'333333', u'profile_image_url_https': u'h
# ...
