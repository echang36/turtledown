# %%
import nltk
from nltk.corpus import stopwords, PlaintextCorpusReader

# %%
cb = PlaintextCorpusReader('cb/', 'polit*.*')
dk = PlaintextCorpusReader('dk/', 'dk*.*')
my = PlaintextCorpusReader('my/', 'polit*.*')
rs = PlaintextCorpusReader('rs/', 'polit*.*')
rwn = PlaintextCorpusReader('rwn/', 'polit*.*')

stop = stopwords.words('english')

# %%
from nltk import FreqDist

d ={}

cb_words = [w for w in set(cb.words()) if w not in stop and 'meta' not in w]
d['CB'] = len(set(cb_words)) / len(set(cb.fileids()))
#print "CB : {} ".format(len(set(cb_words)))

dk_words = [w for w in set(dk.words()) if w not in stop and 'meta' not in w]
d['DK'] = len(set(dk_words)) / len(set(dk.fileids()))
#print "DK : {} ".format(len(set(dk_words)))

my_words = [w for w in set(my.words()) if w not in stop and 'meta' not in w]
d['MY'] = len(set(my_words))/len(set(my.fileids()))
#print "MY : {} ".format(len(set(my_words)))

rs_words = [w for w in set(rs.words()) if w not in stop and 'meta' not in w]
d['RS'] = len(set(rs_words))/len(set(rs.fileids()))
#print "RS : {} ".format(len(set(rs_words)))

rwn_words = [w for w in set(rwn.words()) if w not in stop and 'meta' not in w]
d['RWN'] = len(set(rwn_words))/len(set(rwn.fileids()))
#print "RWN : {} ".format(len(set(rwn_words)))

d
# Out:
# {'CB': 13, 'DK': 9, 'MY': 9, 'RS': 11, 'RWN': 16}

# %%
from pandas import DataFrame
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d
# Out:
# {'CB': 13, 'DK': 9, 'MY': 9, 'RS': 11, 'RWN': 16}

# %%
d.keys()
# Out:
# ['CB', 'MY', 'DK', 'RWN', 'RS']

# %%
d.values()
# Out:
# [13, 9, 9, 16, 11]

# %%
dataset = zip(d.keys(), d.values())
df = DataFrame(data=dataset, columns=['blog','count'])

# %%
df
# Out:
#   blog  count
# 0   CB     13
# 1   MY      9
# 2   DK      9
# 3  RWN     16
# 4   RS     11
#
# [5 rows x 2 columns]

# %%
df['Conservative/Liberal']=['L','L','L','C','C']

# %%
df
# Out:
#   blog  count Conservative/Liberal
# 0   CB     13                    L
# 1   MY      9                    L
# 2   DK      9                    L
# 3  RWN     16                    C
# 4   RS     11                    C
#
# [5 rows x 3 columns]

# %%
df.plot(sort_columns=True, kind='bar', x='blog', y='count')

# %%
import nltk

# %%
cb_bigrams = nltk.bigrams(cb_words)

# %%
cb_bigrams
# Out:
# [('unscientific', 'writings'),
#  ('writings', 'sinjar'),
#  ('sinjar', 'yellow'),
#  ('yellow', 'four'),
#  ('four', 'rocketing'),
#  ('rocketing', 'jihad'),
#  ('jihad', 'commented'),
#  ('commented', 'hanging'),
#  ('hanging', 'conjuring'),
#  ('conjuring', 'woody'),
#  ('woody', 'comically'),
#  ('comically', 'deport'),
#  ('deport', 'aggression'),
#  ('aggression', 'marching'),
#  ('marching', 'looking'),
#  ('looking', 'granting'),
#  ('granting', 'eligible'),
#  ('eligible', 'electricity'),
#  ('electricity', 'landfall'),
#  ('landfall', 'unanswered'),
#  ('unanswered', 'outwit'),
#  ('outwit', 'lori'),
#  ('lori', 'unnecessarily'),
#  ('unnecessarily', 'lord'),
#  ('lord', 'immature'),
#  ('immature', 'peacekeeping'),
#  ('peacekeeping', 'sinking'),
#  ('sinking', 'digit'),
#  ('digit', 'peanuts'),
#  ('peanuts', 'dreamers'),
#  ('dreamers', 'kleiman'),
#  ('kleiman', 'regional'),
#  ('regional', 'montage'),
#  ('montage', 'trojan'),
#  ('trojan', 'pigment'),
#  ('pigment', 'unify'),
#  ('unify', 'drehle'),
#  ('drehle', 'bringing'),
#  ('bringing', 'overturned'),
#  ('overturned', 'basics'),
#  ('basics', 'prize'),
#  ('prize', 'voyeur'),
#  ('voyeur', 'wednesday'),
#  ('wednesday', 'piling'),
#  ('piling', 'lime'),
#  ('lime', 'persisted'),
#  ('persisted', 'hague'),
#  ('hague', 'mlk'),
#  ('mlk', 'deferments'),
#  ('deferments', 'reliable'),
#  ('reliable', 'charter'),
#  ('charter', 'estimations'),
#  ('estimations', 'tired'),
#  ('tired', 'lemieux'),
#  ('lemieux', 'mirage'),
#  ('mirage', 'pulse'),
#  ('pulse', 'mcclaren'),
#  ('mcclaren', 'tires'),
#  ('tires', 'second'),
#  ('second', 'manner'),
#  ('manner', 'resignations'),
#  ('resignations', 'wilson'),
#  ('wilson', 'hilariously'),
#  ('hilariously', 'errors'),
#  ('errors', 'deferred'),
#  ('deferred', 'cooking'),
#  ('cooking', 'contributed'),
#  ('contributed', 'schism'),
#  ('schism', 'negates'),
#  ('negates', 'notches'),
#  ('notches', 'bonuses'),
#  ('bonuses', 'clorox'),
#  ('clorox', 'designing'),
#  ('designing', 'televangelists'),
#  ('televangelists', 'contributes'),
#  ('contributes', 'admiral'),
#  ('admiral', 'shocks'),
#  ('shocks', 'speier'),
#  ('speier', 'specialist'),
#  ('specialist', 'widget'),
#  ('widget', 'misjudged'),
#  ('misjudged', 'hero'),
#  ('hero', 'avert'),
#  ('avert', 'reporter'),
#  ('reporter', 'bureucracy'),
#  ('bureucracy', 'ravenel'),
#  ('ravenel', 'leaning'),
#  ('leaning', 'platitudinous'),
#  ('platitudinous', 'quagmires'),
#  ('quagmires', 'reported'),
#  ('reported', 'china'),
#  ('china', 'cult'),
#  ('cult', 'affiliated'),
#  ('affiliated', 'blei'),
#  ('blei', 'tamping'),
#  ('tamping', 'natured'),
#  ('natured', 'substance'),
#  ('substance', 'unwillingness'),
#  ('unwillingness', 'elaborate'),
#  ('elaborate', 'kumbaya'),
#  ('kumbaya', 'reports'),
#  ('reports', 'controversy'),
#  ('controversy', 'obituaries'),
#  ('obituaries', 'kinsley'),
#  ('kinsley', 'military'),
#  ('military', 'redevelopment'),
#  ('redevelopment', 'cancellation'),
#  ('cancellation', 'criticism'),
#  ('criticism', 'golden'),
#  ('golden', 'divide'),
#  ('divide', 'classification'),
#  ('classification', 'owed'),
#  ('owed', 'explained'),
#  ('explained', 'precincts'),
#  ('precincts', 'hamas'),
#  ('hamas', 'brought'),
#  ('brought', 'shoddy'),
#  ('shoddy', 'mischaracterizing'),
#  ('mischaracterizing', 'cocaine'),
#  ('cocaine', 'unit'),
#  ('unit', 'opponents'),
#  ('opponents', 'cheating'),
#  ('cheating', 'dna'),
#  ('dna', 'spoke'),
#  ('spoke', 'dnc'),
#  ('dnc', 'insecurity'),
#  ('insecurity', 'handedness'),
#  ('handedness', 'dni'),
#  ('dni', 'accommodation'),
#  ('accommodation', 'occupying'),
#  ('occupying', 'folksy'),
#  ('folksy', 'panoply'),
#  ('panoply', 'music'),
#  ('music', 'therefore'),
#  ('therefore', 'passport'),
#  ('passport', 'distortions'),
#  ('distortions', 'strike'),
#  ('strike', 'heralded'),
#  ('heralded', 'sermons'),
#  ('sermons', 'playboy'),
#  ('playboy', 'paperwork'),
#  ('paperwork', 'holy'),
#  ('holy', 'populations'),
#  ('populations', 'successful'),
#  ('successful', 'brings'),
#  ('brings', 'georgian'),
#  ('georgian', 'holt'),
#  ('holt', 'feared'),
#  ('feared', 'yahoo'),
#  ('yahoo', 'hurt'),
#  ('hurt', 'glass'),
#  ('glass', 'export'),
#  ('export', 'harmless'),
#  ('harmless', 'tying'),
#  ('tying', 'inwards'),
#  ('inwards', 'midst'),
#  ('midst', 'hold'),
#  ('hold', 'unpack'),
#  ('unpack', 'nightline'),
#  ('nightline', 'circumstances'),
#  ('circumstances', 'morally'),
#  ('morally', 'locked'),
#  ('locked', 'brutality'),
#  ('brutality', 'pursue'),
#  ('pursue', 'accomplishment'),
#  ('accomplishment', 'rulings'),
#  ('rulings', 'straddle'),
#  ('straddle', 'nationalizing'),
#  ('nationalizing', 'soundbite'),
#  ('soundbite', 'concepts'),
#  ('concepts', 'exhale'),
#  ('exhale', 'apoplexy'),
#  ('apoplexy', 'revenues'),
#  ('revenues', 'admits'),
#  ('admits', 'example'),
#  ('example', 'pinkus'),
#  ('pinkus', 'jindal'),
#  ('jindal', 'protestants'),
#  ('protestants', 'omelets'),
#  ('omelets', 'owes'),
#  ('owes', 'wand'),
#  ('wand', 'wane'),
#  ('wane', 'loosening'),
#  ('loosening', 'household'),
#  ('household', 'beautifully'),
#  ('beautifully', 'organized'),
#  ('organized', 'vehemently'),
#  ('vehemently', 'currency'),
#  ('currency', 'promulgated'),
#  ('promulgated', 'reviewing'),
#  ('reviewing', 'want'),
#  ('want', 'cruising'),
#  ('cruising', 'organizer'),
#  ('organizer', 'absolute'),
#  ('absolute', 'livened'),
#  ('livened', 'provincial'),
#  ('provincial', 'poverty'),
#  ('poverty', 'hoc'),
#  ('hoc', 'worldview'),
#  ('worldview', 'compromisers'),
#  ('compromisers', 'complaining'),
#  ('complaining', 'travel'),
#  ('travel', 'sotu'),
#  ('sotu', 'foser'),
#  ('foser', 'feature'),
#  ('feature', 'leaguers'),
#  ('leaguers', 'revisit'),
#  ('revisit', 'machine'),
#  ('machine', 'methodology'),
#  ('methodology', 'significance'),
#  ('significance', 'palaces'),
#  ('palaces', 'chase'),
#  ('chase', 'preferable'),
#  ('preferable', 'ronnie'),
#  ('ronnie', 'dignified'),
#  ('dignified', 'backpedaled'),
#  ('backpedaled', 'gaming'),
#  ('gaming', 'barbra'),
#  ('barbra', 'huzaifa'),
#  ('huzaifa', 'beauty'),
#  ('beauty', 'inherent'),
#  ('inherent', 'stoller'),
#  ('stoller', 'scottsdale'),
#  ('scottsdale', 'pimps'),
#  ('pimps', 'dinosaurs'),
#  ('dinosaurs', 'wrong'),
#  ('wrong', 'barney'),
#  ('barney', 'quips'),
#  ('quips', 'destined'),
#  ('destined', 'mortars'),
#  ('mortars', 'sentencing'),
#  ('sentencing', 'minimizes'),
#  ('minimizes', 'nonprofit'),
#  ('nonprofit', 'types'),
#  ('types', 'steadfast'),
#  ('steadfast', 'ballroom'),
#  ('ballroom', 'stooped'),
#  ('stooped', 'effective'),
#  ('effective', 'scourge'),
#  ('scourge', 'wins'),
#  ('wins', 'youths'),
#  ('youths', 'revolt'),
#  ('revolt', 'headquarters'),
#  ('headquarters', 'teleprompter'),
#  ('teleprompter', 'sickening'),
#  ('sickening', 'cigarettes'),
#  ('cigarettes', 'ho'),
#  ('ho', 'keeps'),
#  ('keeps', 'democratic'),
#  ('democratic', 'nonsensical'),
#  ('nonsensical', 'wing'),
#  ('wing', 'wind'),
#  ('wind', 'wine'),
#  ('wine', 'senators'),
#  ('senators', 'afterwards'),
#  ('afterwards', 'feedback'),
#  ('feedback', 'welcomed'),
#  ('welcomed', 'dreamed'),
#  ('dreamed', 'confederate'),
#  ('confederate', 'vary'),
#  ('vary', 'whizzing'),
#  ('whizzing', 'partnered'),
#  ('partnered', 'benefited'),
#  ('benefited', 'drawdown'),
#  ('drawdown', 'scalia'),
#  ('scalia', 'rewarded'),
#  ('rewarded', 'owens'),
#  ('owens', 'ebenezer'),
#  ('ebenezer', 'stabbed'),
#  ('stabbed', 'welcomes'),
#  ('welcomes', 'nemecheck'),
#  ('nemecheck', 'deregulating'),
#  ('deregulating', 'fit'),
#  ('fit', 'benign'),
#  ('benign', 'unforeseen'),
#  ('unforeseen', 'heretofore'),
#  ('heretofore', 'fix'),
#  ('fix', 'stevens'),
#  ('stevens', 'auditors'),
#  ('auditors', 'intelligentsia'),
#  ('intelligentsia', 'survivors'),
#  ('survivors', 'rescued'),
#  ('rescued', 'distinguishing'),
#  ('distinguishing', 'accentuating'),
#  ('accentuating', 'hidden'),
#  ('hidden', 'admirable'),
#  ('admirable', 'easier'),
#  ('easier', 'woods'),
#  ('woods', 'chc'),
#  ('chc', 'undercut'),
#  ('undercut', 'glorify'),
#  ('glorify', 'enrich'),
#  ('enrich', 'slate'),
#  ('slate', 'vouchers'),
#  ('vouchers', 'elementary'),
#  ('elementary', 'pontificating'),
#  ('pontificating', 'educating'),
#  ('educating', 'landstuhl'),
#  ('landstuhl', 'mongering'),
#  ('mongering', 'carolinians'),
#  ('carolinians', 'schools'),
#  ('schools', 'beaux'),
#  ('beaux', 'sixteen'),
#  ('sixteen', 'silver'),
#  ('silver', 'saddened'),
#  ('saddened', 'scholar'),
#  ('scholar', 'represents'),
#  ('represents', 'ruth'),
#  ('ruth', 'blazer'),
#  ('blazer', 'inexplicable'),
#  ('inexplicable', 'renditions'),
#  ('renditions', 'debut'),
#  ('debut', 'rino'),
#  ('rino', 'pleasantries'),
#  ('pleasantries', 'clothed'),
#  ('clothed', 'terminology'),
#  ('terminology', 'shrewder'),
#  ('shrewder', 'ingrid'),
#  ('ingrid', 'poisonous'),
#  ('poisonous', 'loyalties'),
#  ('loyalties', 'queued'),
#  ('queued', 'whim'),
#  ('whim', 'financial'),
#  ('financial', 'woes'),
#  ('woes', 'concord'),
#  ('concord', 'series'),
#  ('series', 'itches'),
#  ('itches', 'contracting'),
#  ('contracting', 'whiz'),
#  ('whiz', 'xs'),
#  ('xs', 'friendage'),
#  ('friendage', 'laboratory'),
#  ('laboratory', 'allay'),
#  ('allay', 'truman'),
#  ('truman', 'deadlocked'),
#  ('deadlocked', 'whip'),
#  ('whip', 'hypeman'),
#  ('hypeman', 'forwarding'),
#  ('forwarding', 'barre'),
#  ('barre', 'touts'),
#  ('touts', 'oprah'),
#  ('oprah', 'smu'),
#  ('smu', 'waive'),
#  ('waive', 'freeze'),
#  ('freeze', 'mason'),
#  ('mason', 'unclog'),
#  ('unclog', 're'),
#  ('re', 'encourage'),
#  ('encourage', 'donahue'),
#  ('donahue', 'engineer'),
#  ('engineer', 'strategist'),
#  ('strategist', 'botwin'),
#  ('botwin', 'misrepresentations'),
#  ('misrepresentations', 'foundation'),
#  ('foundation', 'abbott'),
#  ('abbott', 'clarence'),
#  ('clarence', 'assured'),
#  ('assured', 'arraigned'),
#  ('arraigned', 'injecting'),
#  ('injecting', 'naba'),
#  ('naba', 'abramowitz'),
#  ('abramowitz', 'wavered'),
#  ('wavered', 'threatened'),
#  ('threatened', 'surveys'),
#  ('surveys', 'groupthink'),
#  ('groupthink', 'assures'),
#  ('assures', 'enhance'),
#  ('enhance', 'checked'),
#  ('checked', 'estimate'),
#  ('estimate', 'stacy'),
#  ('stacy', 'knit'),
#  ('knit', 'cornerstone'),
#  ('cornerstone', 'appointees'),
#  ('appointees', 'enormous'),
#  ('enormous', 'ate'),
#  ('ate', 'bates'),
#  ('bates', 'exposing'),
#  ('exposing', 'shrum'),
#  ('shrum', 'atm'),
#  ('atm', 'doan'),
#  ('doan', 'heading'),
#  ('heading', 'panetta'),
#  ('panetta', 'ministries'),
#  ('ministries', 'reprimanded'),
#  ('reprimanded', 'disturbed'),
#  ('disturbed', 'competed'),
#  ('competed', 'tempting'),
#  ('tempting', 'kingdom'),
#  ('kingdom', 'mendacity'),
#  ('mendacity', 'clothes'),
#  ('clothes', 'stripe'),
#  ('stripe', 'steroids'),
#  ('steroids', 'dailies'),
#  ('dailies', 'reinvestment'),
#  ('reinvestment', 'subtlety'),
#  ('subtlety', 'verboten'),
#  ('verboten', 'petraeus'),
#  ('petraeus', 'channels'),
#  ('channels', 'wash'),
#  ('wash', 'seinfeld'),
#  ('seinfeld', 'mirrored'),
#  ('mirrored', 'chevron'),
#  ('chevron', 'wasn'),
#  ('wasn', 'warshaw'),
#  ('warshaw', 'clarity'),
#  ('clarity', 'carson'),
#  ('carson', 'olds'),
#  ('olds', 'basketball'),
#  ('basketball', 'crying'),
#  ('crying', 'service'),
#  ('service', 'similarly'),
#  ('similarly', 'fluency'),
#  ('fluency', 'lawsuits'),
#  ('lawsuits', 'engagement'),
#  ('engagement', 'returns'),
#  ('returns', 'touting'),
#  ('touting', 'needed'),
#  ('needed', 'master'),
#  ('master', 'infamous'),
#  ('infamous', 'hypothetical'),
#  ('hypothetical', 'miller'),
#  ('miller', 'legs'),
#  ('legs', 'bitter'),
#  ('bitter', 'ranging'),
#  ('ranging', 'listen'),
#  ('listen', 'danish'),
#  ('danish', 'collapse'),
#  ('collapse', 'voight'),
#  ('voight', 'predictably'),
#  ('predictably', 'peddled'),
#  ('peddled', 'frowned'),
#  ('frowned', 'wisdom'),
#  ('wisdom', 'incoherently'),
#  ('incoherently', 'integrally'),
#  ('integrally', 'predictable'),
#  ('predictable', 'chairwoman'),
#  ('chairwoman', 'scarborough'),
#  ('scarborough', 'positively'),
#  ('positively', 'carrick'),
#  ('carrick', 'ahmed'),
#  ('ahmed', 'peril'),
#  ('peril', 'showed'),
#  ('showed', 'outlaw'),
#  ('outlaw', 'tree'),
#  ('tree', 'rusty'),
#  ('rusty', 'nations'),
#  ('nations', 'project'),
#  ('project', 'idle'),
#  ('idle', 'endure'),
#  ('endure', 'profitable'),
#  ('profitable', 'seminary'),
#  ('seminary', 'feeling'),
#  ('feeling', 'screwup'),
#  ('screwup', 'acquisition'),
#  ('acquisition', 'goya'),
#  ('goya', 'willingness'),
#  ('willingness', 'pinkos'),
#  ('pinkos', 'runner'),
#  ('runner', 'boston'),
#  ('boston', 'spectrum'),
#  ('spectrum', 'tase'),
#  ('tase', 'dawa'),
#  ('dawa', 'giveaway'),
#  ('giveaway', 'extremist'),
#  ('extremist', 'newsrooms'),
#  ('newsrooms', 'alive'),
#  ('alive', 'dozen'),
#  ('dozen', 'affairs'),
#  ('affairs', 'wholesome'),
#  ('wholesome', 'releases'),
#  ('releases', 'regretting'),
#  ('regretting', 'paramedics'),
#  ('paramedics', 'responsible'),
#  ('responsible', 'recommended'),
#  ('recommended', 'causing'),
#  ('causing', 'absorbed'),
#  ('absorbed', 'amusing'),
#  ('amusing', 'doors'),
#  ('doors', 'responsibly'),
#  ('responsibly', 'grips'),
#  ('grips', 'layoffs'),
#  ('layoffs', 'taxation'),
#  ('taxation', 'imprudent'),
#  ('imprudent', 'reelection'),
#  ('reelection', 'pander'),
#  ('pander', 'hurtful'),
#  ('hurtful', 'susie'),
#  ('susie', 'committing'),
#  ('committing', 'mcewan'),
#  ('mcewan', 'thrilled'),
#  ('thrilled', 'screwing'),
#  ('screwing', 'doin'),
#  ('doin', 'limitless'),
#  ('limitless', 'diminishing'),
#  ('diminishing', 'looming'),
#  ('looming', 'victoria'),
#  ('victoria', 'metrics'),
#  ('metrics', 'disjointed'),
#  ('disjointed', 'mouth'),
#  ('mouth', 'letter'),
#  ('letter', 'conceded'),
#  ('conceded', 'retaining'),
#  ('retaining', 'morality'),
#  ('morality', 'singer'),
#  ('singer', 'chemistry'),
#  ('chemistry', 'episode'),
#  ('episode', 'chafets'),
#  ('chafets', 'emailing'),
#  ('emailing', 'professor'),
#  ('professor', 'camp'),
#  ('camp', 'complexities'),
#  ('complexities', 'tech'),
#  ('tech', 'leahy'),
#  ('leahy', 'hastings'),
#  ('hastings', 'scream'),
#  ('scream', 'came'),
#  ('came', 'marvel'),
#  ('marvel', 'saying'),
#  ('saying', 'signatures'),
#  ('signatures', 'bomb'),
#  ('bomb', 'departing'),
#  ('departing', 'meetings'),
#  ('meetings', 'advisors'),
#  ('advisors', 'teresa'),
#  ('teresa', 'apostasies'),
#  ('apostasies', 'sexist'),
#  ('sexist', 'heckler'),
#  ('heckler', 'undue'),
#  ('undue', 'qaeda'),
#  ('qaeda', 'gauge'),
#  ('gauge', 'malleable'),
#  ('malleable', 'strazar'),
#  ('strazar', 'participate'),
#  ('participate', 'falsehoods'),
#  ('falsehoods', 'arrow'),
#  ('arrow', 'tempted'),
#  ('tempted', 'nea'),
#  ('nea', 'islamo'),
#  ('islamo', 'hounded'),
#  ('hounded', 'lessons'),
#  ('lessons', 'apace'),
#  ('apace', 'touches'),
#  ('touches', 'busy'),
#  ('busy', 'amsuing'),
#  ('amsuing', 'regurgitates'),
#  ('regurgitates', 'shuffling'),
#  ('shuffling', 'headline'),
#  ('headline', 'menu'),
#  ('menu', 'underpants'),
#  ('underpants', 'decry'),
#  ('decry', 'bust'),
#  ('bust', 'appreciated'),
#  ('appreciated', 'accelerate'),
#  ('accelerate', 'rico'),
#  ('rico', 'bush'),
#  ('bush', 'statehouse'),
#  ('statehouse', 'touched'),
#  ('touched', 'rich'),
#  ('rich', 'foolishly'),
#  ('foolishly', 'rice'),
#  ('rice', 'schmensylvania'),
#  ('schmensylvania', 'pocked'),
#  ('pocked', 'plate'),
#  ('plate', 'klein'),
#  ('klein', 'champaign'),
#  ('champaign', 'heartbeats'),
#  ('heartbeats', 'denounce'),
#  ('denounce', 'psychiatric'),
#  ('psychiatric', 'foremost'),
#  ('foremost', 'pocket'),
#  ('pocket', 'resilient'),
#  ('resilient', 'sniping'),
#  ('sniping', 'clumsiness'),
#  ('clumsiness', 'reversal'),
#  ('reversal', 'altogether'),
#  ('altogether', 'chyron'),
#  ('chyron', 'midterms'),
#  ('midterms', 'net'),
#  ('net', 'tawdry'),
#  ('tawdry', 'preemptively'),
#  ('preemptively', 'profoundly'),
#  ('profoundly', 'kcci'),
#  ('kcci', 'increasing'),
#  ('increasing', 'autistic'),
#  ('autistic', 'strossen'),
#  ('strossen', 'nicely'),
#  ('nicely', 'maverick'),
#  ('maverick', 'dipping'),
#  ('dipping', 'thaddeus'),
#  ('thaddeus', 'patch'),
#  ('patch', 'stunningly'),
#  ('stunningly', 'release'),
#  ('release', 'attends'),
#  ('attends', 'respond'),
#  ('respond', 'conant'),
#  ('conant', 'blew'),
#  ('blew', 'benazir'),
#  ('benazir', 'disaster'),
#  ('disaster', 'fair'),
#  ('fair', 'clarified'),
#  ('clarified', 'branding'),
#  ('branding', 'sensitivity'),
#  ('sensitivity', 'proadcast'),
#  ('proadcast', 'deemed'),
#  ('deemed', 'faiz'),
#  ('faiz', 'recruit'),
#  ('recruit', 'unexpectedly'),
#  ('unexpectedly', 'mccainamigos'),
#  ('mccainamigos', 'goodnight'),
#  ('goodnight', 'expedience'),
#  ('expedience', 'result'),
#  ('result', 'fail'),
#  ('fail', 'resigned'),
#  ('resigned', 'hammer'),
#  ('hammer', 'simi'),
#  ('simi', 'best'),
#  ('best', 'intellects'),
#  ('intellects', 'sunbay'),
#  ('sunbay', 'campaigners'),
#  ('campaigners', 'pressured'),
#  ('pressured', 'ambitions'),
#  ('ambitions', 'lots'),
#  ('lots', 'ackerman'),
#  ('ackerman', 'hunker'),
#  ('hunker', 'wikipedia'),
#  ('wikipedia', 'stealthy'),
#  ('stealthy', 'lott'),
#  ('lott', 'vandehei'),
#  ('vandehei', 'pressures'),
#  ('pressures', 'stamps'),
#  ('stamps', 'score'),
#  ('score', 'melissa'),
#  ('melissa', 'dadey'),
#  ('dadey', 'pilloried'),
#  ('pilloried', 'mailings'),
#  ('mailings', 'ooze'),
#  ('ooze', 'preserve'),
#  ('preserve', 'discipline'),
#  ('discipline', 'lamar'),
#  ('lamar', 'never'),
#  ('never', 'schwarzkopf'),
#  ('schwarzkopf', 'nationwide'),
#  ('nationwide', 'nature'),
#  ('nature', 'rolled'),
#  ('rolled', 'felony'),
#  ('felony', 'abandons'),
#  ('abandons', 'authorizing'),
#  ('authorizing', 'embracement'),
#  ('embracement', 'halloween'),
#  ('halloween', 'wtc'),
#  ('wtc', 'unseemly'),
#  ('unseemly', 'extent'),
#  ('extent', 'defiance'),
#  ('defiance', 'toles'),
#  ('toles', 'carbon'),
#  ('carbon', 'debt'),
#  ('debt', 'pity'),
#  ('pity', 'accident'),
#  ('accident', 'trickster'),
#  ('trickster', 'sacrificing'),
#  ('sacrificing', 'brown'),
#  ('brown', 'disdain'),
#  ('disdain', 'country'),
#  ('country', 'pits'),
#  ('pits', 'conclusions'),
#  ('conclusions', 'heating'),
#  ('heating', 'demanded'),
#  ('demanded', 'proved'),
#  ('proved', 'planned'),
#  ('planned', 'logic'),
#  ('logic', 'installments'),
#  ('installments', 'federalism'),
#  ('federalism', 'argue'),
#  ('argue', 'betrayed'),
#  ('betrayed', 'asked'),
#  ('asked', 'schmooze'),
#  ('schmooze', 'eradicate'),
#  ('eradicate', 'pre'),
#  ('pre', 'untruths'),
#  ('untruths', 'vail'),
#  ('vail', 'irresponsible'),
#  ('irresponsible', 'dorm'),
#  ('dorm', 'broward'),
#  ('broward', 'roam'),
#  ('roam', 'irresponsibly'),
#  ('irresponsibly', 'pregnancy'),
#  ('pregnancy', 'truthful'),
#  ('truthful', 'fema'),
#  ('fema', 'smackdown'),
#  ('smackdown', 'armored'),
#  ('armored', 'frc'),
#  ('frc', 'billing'),
#  ('billing', 'shouting'),
#  ('shouting', 'union'),
#  ('union', 'economically'),
#  ('economically', 'newt'),
#  ('newt', 'much'),
#  ('much', 'stadium'),
#  ('stadium', 'privilege'),
#  ('privilege', 'pro'),
#  ('pro', 'gladly'),
#  ('gladly', 'testimonies'),
#  ('testimonies', 'dots'),
#  ('dots', 'doldrums'),
#  ('doldrums', 'life'),
#  ('life', 'ponnuru'),
#  ('ponnuru', 'retrospect'),
#  ('retrospect', 'spit'),
#  ('spit', 'eastern'),
#  ('eastern', 'worker'),
#  ('worker', 'dave'),
#  ('dave', 'kids'),
#  ('kids', 'nexis'),
#  ('nexis', 'slap'),
#  ('slap', 'child'),
#  ('child', 'worked'),
#  ('worked', 'haters'),
#  ('haters', 'spin'),
#  ('spin', 'chill'),
#  ('chill', 'commerce'),
#  ('commerce', 'presidency'),
#  ('presidency', 'easter'),
#  ('easter', 'technologically'),
#  ('technologically', 'professionally'),
#  ('professionally', 'inch'),
#  ('inch', 'employ'),
#  ('employ', 'misconstrued'),
#  ('misconstrued', 'rescinds'),
#  ('rescinds', 'unloading'),
#  ('unloading', 'seduc'),
#  ('seduc', 'appeals'),
#  ('appeals', 'flooding'),
#  ('flooding', 'k'),
#  ('k', 'remembering'),
#  ('remembering', 'ridiculously'),
#  ('ridiculously', 'vulnerability'),
#  ('vulnerability', 'played'),
#  ('played', 'conditioned'),
#  ('conditioned', 'fiorina'),
#  ('fiorina', 'characterize'),
#  ('characterize', 'eighteen'),
#  ('eighteen', 'levied'),
#  ('levied', 'campaigning'),
#  ('campaigning', 'expedited'),
#  ('expedited', 'specter'),
#  ('specter', 'trusted'),
#  ('trusted', 'memorial'),
#  ('memorial', 'dhl'),
#  ('dhl', 'severity'),
#  ('severity', 'credit'),
#  ('credit', 'things'),
#  ('things', 'cumulative'),
#  ('cumulative', 'diiulio'),
#  ('diiulio', 'fatal'),
#  ('fatal', 'feuding'),
#  ('feuding', 'split'),
#  ('split', 'babies'),
#  ('babies', 'elliott'),
#  ('elliott', 'principals'),
#  ('principals', 'dhs'),
#  ('dhs', 'rebound'),
#  ('rebound', 'european'),
#  ('european', 'fairly'),
#  ('fairly', 'beachhead'),
#  ('beachhead', 'jerked'),
#  ('jerked', 'cindy'),
#  ('cindy', 'inadvertently'),
#  ('inadvertently', 'typhoid'),
#  ('typhoid', 'permit'),
#  ('permit', 'qualifications'),
#  ('qualifications', 'workforce'),
#  ('workforce', 'marched'),
#  ('marched', 'fishy'),
#  ('fishy', 'reruns'),
#  ('reruns', 'freethoughtaction'),
#  ('freethoughtaction', 'sjc'),
#  ('sjc', 'wives'),
#  ('wives', 'tune'),
#  ('tune', 'registering'),
#  ('registering', 'simulates'),
#  ('simulates', 'oberweis'),
#  ('oberweis', 'furlough'),
#  ('furlough', 'askance'),
#  ('askance', 'echoed'),
#  ('echoed', 'academic'),
#  ('academic', 'subpoena'),
#  ('subpoena', 'quantitative'),
#  ('quantitative', 'backhanded'),
#  ('backhanded', 'corporate'),
#  ('corporate', 'chessboard'),
#  ('chessboard', 'opinions'),
#  ('opinions', 'spurred'),
#  ('spurred', 'capitol'),
#  ('capitol', 'appropriately'),
#  ('appropriately', 'distribute'),
#  ('distribute', 'slayings'),
#  ('slayings', 'terrorist'),
#  ('terrorist', 'beset'),
#  ('beset', 'disguise'),
#  ('disguise', 'financially'),
#  ('financially', 'exclaiming'),
#  ('exclaiming', 'plight'),
#  ('plight', 'credited'),
#  ('credited', 'portrayed'),
#  ('portrayed', 'succeeding'),
#  ('succeeding', 'previous'),
#  ('previous', 'handshake'),
#  ('handshake', 'enters'),
#  ('enters', 'atrial'),
#  ('atrial', 'ease'),
#  ('ease', 'advancement'),
#  ('advancement', 'woodstock'),
#  ('woodstock', 'hay'),
#  ('hay', 'disparity'),
#  ('disparity', 'collections'),
#  ('collections', 'innocent'),
#  ('innocent', 'prison'),
#  ('prison', 'falter'),
#  ('falter', 'hat'),
#  ('hat', 'romano'),
#  ('romano', 'municipal'),
#  ('municipal', 'casually'),
#  ('casually', 'elders'),
#  ('elders', 'survival'),
#  ('survival', 'posed'),
#  ('posed', 'possible'),
#  ('possible', 'awhile'),
#  ('awhile', 'firmer'),
#  ('firmer', 'unequivocally'),
#  ('unequivocally', 'possibly'),
#  ('possibly', 'indicative'),
#  ('indicative', 'gridlock'),
#  ('gridlock', 'birth'),
#  ('birth', 'ratcheting'),
#  ('ratcheting', 'distortion'),
#  ('distortion', 'imposed'),
#  ('imposed', 'shadow'),
#  ('shadow', 'unique'),
#  ('unique', 'tolerable'),
#  ('tolerable', 'massively'),
#  ('massively', 'desire'),
#  ('desire', 'anticipation'),
#  ('anticipation', 'paraphrase'),
#  ('paraphrase', 'bobby'),
#  ('bobby', 'remind'),
#  ('remind', 'misled'),
#  ('misled', 'steps'),
#  ('steps', 'temperamentally'),
#  ('temperamentally', 'baptists'),
#  ('baptists', 'sympathize'),
#  ('sympathize', 'basra'),
#  ('basra', 'battlefield'),
#  ('battlefield', 'attorney'),
#  ('attorney', 'right'),
#  ('right', 'old'),
#  ('old', 'ole'),
#  ('ole', 'crowd'),
#  ('crowd', 'people'),
#  ('people', 'czech'),
#  ('czech', 'plouffe'),
#  ('plouffe', 'ballooned'),
#  ('ballooned', 'deflection'),
#  ('deflection', 'defeatists'),
#  ('defeatists', 'captive'),
#  ('captive', 'commonplace'),
#  ('commonplace', 'srebrenica'),
#  ('srebrenica', 'chopper'),
#  ('chopper', 'insistence'),
#  ('insistence', 'billboard'),
#  ('billboard', 'aspen'),
#  ('aspen', 'harassment'),
#  ('harassment', 'creep'),
#  ('creep', 'enemies'),
#  ('enemies', 'chorus'),
#  ('chorus', 'attendees'),
#  ('attendees', 'bottom'),
#  ('bottom', 'whiffing'),
#  ('whiffing', 'circumvent'),
#  ('circumvent', 'myung'),
#  ('myung', 'fox'),
#  ('fox', 'creative'),
#  ('creative', 'contributing'),
#  ('contributing', 'foe'),
#  ('foe', 'disheartened'),
#  ('disheartened', 'flopping'),
#  ('flopping', 'tertiary'),
#  ('tertiary', 'frum'),
#  ('frum', 'pondered'),
#  ('pondered', 'umm'),
#  ('umm', 'surging'),
#  ('surging', 'trite'),
#  ('trite', 'stints'),
#  ('stints', 'theological'),
#  ('theological', 'palatable'),
#  ('palatable', 'shakes'),
#  ('shakes', 'substitutes'),
#  ('substitutes', 'secularists'),
#  ('secularists', 'lefty'),
#  ('lefty', 'binder'),
#  ('binder', 'brigades'),
#  ('brigades', 'shifting'),
#  ('shifting', 'defensive'),
#  ('defensive', 'tribes'),
#  ('tribes', 'losing'),
#  ('losing', 'memorable'),
#  ('memorable', 'bowing'),
#  ('bowing', 'disdains'),
#  ('disdains', 'shaken'),
#  ('shaken', 'projected'),
#  ('projected', 'rematch'),
#  ('rematch', 'dollars'),
#  ('dollars', 'citizens'),
#  ('citizens', 'disqualifies'),
#  ('disqualifies', 'o'),
#  ('o', 'ptsd'),
#  ('ptsd', 'sycophant'),
#  ('sycophant', 'leverage'),
#  ('leverage', 'suggestions'),
#  ('suggestions', 'palestinians'),
#  ('palestinians', 'slightly'),
#  ('slightly', 'nixon'),
#  ('nixon', 'mamby'),
#  ('mamby', 'raised'),
#  ('raised', 'statements'),
#  ('statements', 'facility'),
#  ('facility', 'neocon'),
#  ('neocon', 'material'),
#  ('material', 'marshall'),
#  ('marshall', 'mba'),
#  ('mba', 'son'),
#  ('son', 'undermining'),
#  ('undermining', 'beings'),
#  ('beings', 'magazines'),
#  ('magazines', 'raises'),
#  ('raises', 'wrap'),
#  ('wrap', 'pairs'),
#  ('pairs', 'shoots'),
#  ('shoots', 'reducing'),
#  ('reducing', 'defendants'),
#  ('defendants', 'coauthor'),
#  ('coauthor', 'unambiguous'),
#  ('unambiguous', 'authorizes'),
#  ('authorizes', 'addington'),
#  ('addington', 'fabric'),
#  ('fabric', 'waits'),
#  ('waits', 'support'),
#  ('support', 'constantly'),
#  ('constantly', 'knowing'),
#  ('knowing', 'raped'),
#  ('raped', 'avail'),
#  ('avail', 'absolutely'),
#  ('absolutely', 'joseph'),
#  ('joseph', 'hothead'),
#  ('hothead', 'authorized'),
#  ('authorized', 'greatness'),
#  ('greatness', 'jane'),
#  ('jane', 'tamp'),
#  ('tamp', 'icon'),
#  ('icon', 'halls'),
#  ('halls', 'launching'),
#  ('launching', 'happy'),
#  ('happy', 'tussle'),
#  ('tussle', 'underestimated'),
#  ('underestimated', 'offer'),
#  ('offer', 'understandably'),
#  ('understandably', 'forming'),
#  ('forming', 'tigers'),
#  ('tigers', 'tirades'),
#  ('tirades', 'drummond'),
#  ('drummond', 'melanie'),
#  ('melanie', 'understandable'),
#  ('understandable', 'reinventing'),
#  ('reinventing', 'survive'),
#  ('survive', 'delegation'),
#  ('delegation', 'congratulations'),
#  ('congratulations', 'parroted'),
#  ('parroted', 'humbled'),
#  ('humbled', 'silliness'),
#  ('silliness', 'masquerading'),
#  ('masquerading', 'milbloggers'),
#  ('milbloggers', 'inside'),
#  ('inside', 'officiated'),
#  ('officiated', 'devices'),
#  ('devices', 'unanimous'),
#  ('unanimous', 'torturing'),
#  ('torturing', 'entitlement'),
#  ('entitlement', 'smashed'),
#  ('smashed', 'dues'),
#  ('dues', 'quarantining'),
#  ('quarantining', 'juvenile'),
#  ('juvenile', 'proud'),
#  ('proud', 'liberal'),
#  ('liberal', 'mideast'),
#  ('mideast', 'centrifuges'),
#  ('centrifuges', 'implications'),
#  ('implications', 'mirror'),
#  ('mirror', 'textbook'),
#  ('textbook', 'crumble'),
#  ('crumble', 'biden'),
#  ('biden', 'angola'),
#  ('angola', 'proves'),
#  ('proves', 'exist'),
#  ('exist', 'wyly'),
#  ('wyly', 'accounting'),
#  ('accounting', 'pretrial'),
#  ('pretrial', 'negotiations'),
#  ('negotiations', 'posting'),
#  ('posting', 'protested'),
#  ('protested', 'solicitation'),
#  ('solicitation', 'eventual'),
#  ('eventual', 'floor'),
#  ('floor', 'fantasyland'),
#  ('fantasyland', 'relax'),
#  ('relax', 'actor'),
#  ('actor', 'uttered'),
#  ('uttered', 'detracts'),
#  ('detracts', 'warms'),
#  ('warms', 'role'),
#  ('role', 'overturning'),
#  ('overturning', 'griswold'),
#  ('griswold', 'jenkins'),
#  ('jenkins', 'irresistible'),
#  ('irresistible', 'superfluous'),
#  ('superfluous', 'roll'),
#  ('roll', 'ike'),
#  ('ike', 'intend'),
#  ('intend', 'models'),
#  ('models', 'interjected'),
#  ('interjected', 'sunroof'),
#  ('sunroof', 'literalist'),
#  ('literalist', 'uncharitable'),
#  ('uncharitable', 'muslims'),
#  ('muslims', 'invested'),
#  ('invested', 'miranda'),
#  ('miranda', 'rolling'),
#  ('rolling', 'cleaver'),
#  ('cleaver', 'explosions'),
#  ('explosions', 'loony'),
#  ('loony', 'reorganization'),
#  ('reorganization', 'lowdown'),
#  ('lowdown', 'ottawa'),
#  ('ottawa', 'ordination'),
#  ('ordination', 'time'),
#  ('time', 'push'),
#  ('push', 'banners'),
#  ('banners', 'quantity'),
#  ('quantity', 'inc'),
#  ('inc', 'jed'),
#  ('jed', 'subvert'),
#  ('subvert', 'slope'),
#  ('slope', 'sebelius'),
#  ('sebelius', 'proficient'),
#  ('proficient', 'cincinnati'),
#  ('cincinnati', 'corps'),
#  ('corps', 'whoever'),
#  ('whoever', 'jmm'),
#  ('jmm', 'ost'),
#  ('ost', 'umbrage'),
#  ('umbrage', 'skate'),
#  ('skate', 'jarring'),
#  ('jarring', 'osc'),
#  ('osc', 'chait'),
#  ('chait', 'hole'),
#  ('hole', 'elleithee'),
#  ('elleithee', 'vet'),
#  ('vet', 'flubbed'),
#  ('flubbed', 'pell'),
#  ('pell', 'caldwell'),
#  ('caldwell', 'methodically'),
#  ('methodically', 'suspending'),
#  ('suspending', 'german'),
#  ('german', 'prolonging'),
#  ('prolonging', 'carpetbag'),
#  ('carpetbag', 'platitudes'),
#  ('platitudes', 'hurd'),
#  ('hurd', 'oversight'),
#  ('oversight', 'methodical'),
#  ('methodical', 'verbally'),
#  ('verbally', 'persevere'),
#  ('persevere', 'glory'),
#  ('glory', 'paychecks'),
#  ('paychecks', 'jerk'),
#  ('jerk', 'allegations'),
#  ('allegations', 'consolidation'),
#  ('consolidation', 'spate'),
#  ('spate', 'choice'),
#  ('choice', 'whit'),
#  ('whit', 'servicing'),
#  ('servicing', 'stays'),
#  ('stays', 'spats'),
#  ('spats', 'exact'),
#  ('exact', 'overstock'),
#  ('overstock', 'minute'),
#  ('minute', 'glassman'),
#  ('glassman', 'cooks'),
#  ('cooks', 'judaism'),
#  ('judaism', 'reining'),
#  ('reining', 'tear'),
#  ('tear', 'gooily'),
#  ('gooily', 'homebody'),
#  ('homebody', 'cameo'),
#  ('cameo', 'mahe'),
#  ('mahe', 'leave'),
#  ('leave', 'solved'),
#  ('solved', 'settle'),
#  ('settle', 'subway'),
#  ('subway', 'korb'),
#  ('korb', 'team'),
#  ('team', 'shelley'),
#  ('shelley', 'skewer'),
#  ('skewer', 'speculation'),
#  ('speculation', 'nbra'),
#  ('nbra', 'unaware'),
#  ('unaware', 'prevent'),
#  ('prevent', 'spiritual'),
#  ('spiritual', 'thinkers'),
#  ('thinkers', 'occurrence'),
#  ('occurrence', 'findings'),
#  ('findings', 'insignificant'),
#  ('insignificant', 'eagleburger'),
#  ('eagleburger', 'trails'),
#  ('trails', 'exaggerator'),
#  ('exaggerator', 'prediction'),
#  ('prediction', 'sign'),
#  ('sign', 'adulation'),
#  ('adulation', 'chopping'),
#  ('chopping', 'shirts'),
#  ('shirts', 'jamison'),
#  ('jamison', 'educate'),
#  ('educate', 'elton'),
#  ('elton', 'essence'),
#  ('essence', 'jeopardy'),
#  ('jeopardy', 'celebrated'),
#  ('celebrated', 'realizing'),
#  ('realizing', 'sadrists'),
#  ('sadrists', 'current'),
#  ('current', 'sixpack'),
#  ('sixpack', 'freaks'),
#  ('freaks', 'brookings'),
#  ('brookings', 'falling'),
#  ('falling', 'boost'),
#  ('boost', 'unintentionally'),
#  ('unintentionally', 'drafted'),
#  ('drafted', 'jury'),
#  ('jury', 'michele'),
#  ('michele', 'assertive'),
#  ('assertive', 'funeral'),
#  ('funeral', 'understanding'),
#  ('understanding', 'contemplate'),
#  ('contemplate', 'consult'),
#  ('consult', 'egypt'),
#  ('egypt', 'yards'),
#  ('yards', 'address'),
#  ('address', 'alone'),
#  ('alone', 'along'),
#  ('along', 'momentous'),
#  ('momentous', 'neville'),
#  ('neville', 'effusive'),
#  ('effusive', 'brilliant'),
#  ('brilliant', 'studied'),
#  ('studied', 'funded'),
#  ('funded', 'commonly'),
#  ('commonly', 'accomplished'),
#  ('accomplished', 'ineffective'),
#  ('ineffective', 'crumbled'),
#  ('crumbled', 'studies'),
#  ('studies', 'durbin'),
#  ('durbin', 'concealed'),
#  ('concealed', 'mindedness'),
#  ('mindedness', 'love'),
#  ('love', 'proportion'),
#  ('proportion', 'prefer'),
#  ('prefer', 'logical'),
#  ('logical', 'bloody'),
#  ('bloody', 'coinciding'),
#  ('coinciding', 'residual'),
#  ('residual', 'betraying'),
#  ('betraying', 'fake'),
#  ('fake', 'karadzic'),
#  ('karadzic', 'flagging'),
#  ('flagging', 'carol'),
#  ('carol', 'sky'),
#  ('sky', 'opposes'),
#  ('opposes', 'veneer'),
#  ('veneer', 'working'),
#  ('working', 'perished'),
#  ('perished', 'positive'),
#  ('positive', 'angry'),
#  ('angry', 'hyatt'),
#  ('hyatt', 'blackwater'),
#  ('blackwater', 'predictions'),
#  ('predictions', 'distancing'),
#  ('distancing', 'imaginations'),
#  ('imaginations', 'wood'),
#  ('wood', 'opposed'),
#  ('opposed', 'wondering'),
#  ('wondering', 'unjust'),
#  ('unjust', 'films'),
#  ('films', 'scope'),
#  ('scope', 'prosecutor'),
#  ('prosecutor', 'loving'),
#  ('loving', 'scratched'),
#  ('scratched', 'introducing'),
#  ('introducing', 'artillery'),
#  ('artillery', 'mclane'),
#  ('mclane', 'marbles'),
#  ('marbles', 'afford'),
#  ('afford', 'apparent'),
#  ('apparent', 'refrain'),
#  ('refrain', 'approving'),
#  ('approving', 'misquoting'),
#  ('misquoting', 'visual'),
#  ('visual', 'louisville'),
#  ('louisville', 'everywhere'),
#  ('everywhere', 'virtue'),
#  ('virtue', 'sycophancy'),
#  ('sycophancy', 'rendered'),
#  ('rendered', 'porous'),
#  ('porous', 'behalf'),
#  ('behalf', 'rebounding'),
#  ('rebounding', 'valued'),
#  ('valued', 'deserved'),
#  ('deserved', 'wingers'),
#  ('wingers', 'originally'),
#  ('originally', 'pretend'),
#  ('pretend', 'abortion'),
#  ('abortion', 'privy'),
#  ('privy', 'believer'),
#  ('believer', 'believes'),
#  ('believes', 'strain'),
#  ('strain', 'trounced'),
#  ('trounced', 'printing'),
#  ('printing', 'values'),
#  ('values', 'albright'),
#  ('albright', 'following'),
#  ('following', 'webster'),
#  ('webster', 'detached'),
#  ('detached', 'uighur'),
#  ('uighur', 'gunfire'),
#  ('gunfire', 'admired'),
#  ('admired', 'parishes'),
#  ('parishes', 'awesome'),
#  ('awesome', 'reagans'),
#  ('reagans', 'mailboxes'),
#  ('mailboxes', 'nascar'),
#  ('nascar', 'locks'),
#  ('locks', 'incremental'),
#  ('incremental', 'graduation'),
#  ('graduation', 'unveiled'),
#  ('unveiled', 'allowed'),
#  ('allowed', 'bracewell'),
#  ('bracewell', 'offense'),
#  ('offense', 'stole'),
#  ('stole', 'listens'),
#  ('listens', 'ramesh'),
#  ('ramesh', 'monitoring'),
#  ('monitoring', 'winter'),
#  ('winter', 'savor'),
#  ('savor', 'divided'),
#  ('divided', 'sudden'),
#  ('sudden', 'thanking'),
#  ('thanking', 'immune'),
#  ('immune', 'contrasts'),
#  ('contrasts', 'elephant'),
#  ('elephant', 'coleman'),
#  ('coleman', 'divider'),
#  ('divider', 'divides'),
#  ('divides', 'preferably'),
#  ('preferably', 'laundry'),
#  ('laundry', 'landmark'),
#  ('landmark', 'rigors'),
#  ('rigors', 'technocrat'),
#  ('technocrat', 'blasting'),
#  ('blasting', 'latta'),
#  ('latta', 'misjudgments'),
#  ('misjudgments', 'expectation'),
#  ('expectation', 'rehabilitate'),
#  ('rehabilitate', 'applications'),
#  ('applications', 'explored'),
#  ('explored', 'date'),
#  ('date', 'suck'),
#  ('suck', 'data'),
#  ('data', 'misspoken'),
#  ('misspoken', 'stress'),
#  ('stress', 'surfing'),
#  ('surfing', 'natural'),
#  ('natural', 'sectors'),
#  ('sectors', 'conscious'),
#  ('conscious', 'ss'),
#  ('ss', 'sr'),
#  ('sr', 'wheelchair'),
#  ('wheelchair', 'ordinarily'),
#  ('ordinarily', 'st'),
#  ('st', 'regressive'),
#  ('regressive', 'sandbox'),
#  ('sandbox', 'skirmish'),
#  ('skirmish', 'definitions'),
#  ('definitions', 'pollution'),
#  ('pollution', 'pulled'),
#  ('pulled', 'se'),
#  ('se', 'publish'),
#  ('publish', 'drunken'),
#  ('drunken', 'unsolicited'),
#  ('unsolicited', 'insurgency'),
#  ('insurgency', 'regulates'),
#  ('regulates', 'nfortunately'),
#  ('nfortunately', 'unacceptable'),
#  ('unacceptable', 'years'),
#  ('years', 'professors'),
#  ('professors', 'course'),
#  ('course', 'yearn'),
#  ('yearn', 'experiments'),
#  ('experiments', 'maneuvered'),
#  ('maneuvered', 'omitting'),
#  ('omitting', 'unfavorable'),
#  ('unfavorable', 'deity'),
#  ('deity', 'tendency'),
#  ('tendency', 'thoughtfulness'),
#  ('thoughtfulness', 'constituted'),
#  ('constituted', 'disconnect'),
#  ('disconnect', 'solace'),
#  ('solace', 'internationally'),
#  ('internationally', 'decrying'),
#  ('decrying', 'lackluster'),
#  ('lackluster', 'jim'),
#  ('jim', 'troubles'),
#  ('troubles', 'stupidity'),
#  ('stupidity', 'tort'),
#  ('tort', 'creations'),
#  ('creations', 'suspicion'),
#  ('suspicion', 'stroll'),
#  ('stroll', 'constitutes'),
#  ('constitutes', 'spotlighting'),
#  ('spotlighting', 'suspension'),
#  ('suspension', 'bipartisan'),
#  ('bipartisan', 'decades'),
#  ('decades', 'diwali'),
#  ('diwali', 'petition'),
#  ('petition', 'ideal'),
#  ('ideal', 'retails'),
#  ('retails', 'thereby'),
#  ('thereby', 'civilian'),
#  ('civilian', 'smarter'),
#  ('smarter', 'nation'),
#  ('nation', 'records'),
#  ('records', 'compelled'),
#  ('compelled', 'awaited'),
#  ('awaited', 'subscribers'),
#  ('subscribers', 'arriving'),
#  ('arriving', 'benenson'),
#  ('benenson', 'twilight'),
#  ('twilight', 'maintaining'),
#  ('maintaining', 'matched'),
#  ('matched', 'liberation'),
#  ('liberation', 'deady'),
#  ('deady', 'shouted'),
#  ('shouted', 'materialized'),
#  ('materialized', 'didn'),
#  ('didn', 'establishing'),
#  ('establishing', 'bowling'),
#  ('bowling', 'instability'),
#  ('instability', 'amnesty'),
#  ('amnesty', 'quarter'),
#  ('quarter', 'carelessly'),
#  ('carelessly', 'stalling'),
#  ('stalling', 'square'),
#  ('square', 'farce'),
#  ('farce', 'exelon'),
#  ('exelon', 'revised'),
#  ('revised', 'breakthrough'),
#  ('breakthrough', 'remembrance'),
#  ('remembrance', 'disappearing'),
#  ('disappearing', 'sponsor'),
#  ('sponsor', 'entering'),
#  ('entering', 'sexually'),
#  ('sexually', 'disasters'),
#  ('disasters', 'flustered'),
#  ('flustered', 'giddy'),
#  ('giddy', 'crotchety'),
#  ('crotchety', 'actively'),
#  ('actively', 'interned'),
#  ('interned', 'astray'),
#  ('astray', 'ordain'),
#  ('ordain', 'biographers'),
#  ('biographers', 'believers'),
#  ('believers', 'seriously'),
#  ('seriously', 'investigation'),
#  ('investigation', 'trauma'),
#  ('trauma', 'internet'),
#  ('internet', 'suggesting'),
#  ('suggesting', 'formula'),
#  ('formula', 'unifying'),
#  ('unifying', 'fitch'),
#  ('fitch', 'plotting'),
#  ('plotting', 'dodgers'),
#  ('dodgers', 'ascendant'),
#  ('ascendant', 'siege'),
#  ('siege', 'million'),
#  ('million', 'netroots'),
#  ('netroots', 'possibility'),
#  ('possibility', 'quite'),
#  ('quite', 'disrespect'),
#  ('disrespect', 'bumps'),
#  ('bumps', 'pled'),
#  ('pled', 'complicated'),
#  ('complicated', 'besides'),
#  ('besides', 'vegetarians'),
#  ('vegetarians', 'unnamed'),
#  ('unnamed', 'remainder'),
#  ('remainder', 'reevaluating'),
#  ('reevaluating', 'patronage'),
#  ('patronage', 'shores'),
#  ('shores', 'training'),
#  ('training', 'lithwick'),
#  ('lithwick', 'locations'),
#  ('locations', 'collapsing'),
#  ('collapsing', 'programming'),
#  ('programming', 'modest'),
#  ('modest', 'kathleen'),
#  ('kathleen', 'massive'),
#  ('massive', 'thurmond'),
#  ('thurmond', 'timelines'),
#  ('timelines', 'doddering'),
#  ('doddering', 'brokeback'),
#  ('brokeback', 'rumsfeld'),
#  ('rumsfeld', 'neglect'),
#  ('neglect', 'intuition'),
#  ('intuition', 'saving'),
#  ('saving', 'curiosity'),
#  ('curiosity', 'garnering'),
#  ('garnering', 'reveals'),
#  ('reveals', 'spoken'),
#  ('spoken', 'clause'),
#  ('clause', 'potter'),
#  ('potter', 'one'),
#  ('one', 'opec'),
#  ('opec', 'submit'),
#  ('submit', 'spanish'),
#  ('spanish', 'vote'),
#  ('vote', 'open'),
#  ('open', 'kerrey'),
#  ('kerrey', 'exaggerations'),
#  ('exaggerations', 'city'),
#  ('city', 'boulevard'),
#  ('boulevard', 'wrath'),
#  ('wrath', 'occupy'),
#  ('occupy', 'recoupment'),
#  ('recoupment', 'bite'),
#  ('bite', 'puppies'),
#  ('puppies', 'stocks'),
#  ('stocks', 'indicate'),
#  ('indicate', 'teacher'),
#  ('teacher', 'draft'),
#  ('draft', 'dissipate'),
#  ('dissipate', 'convene'),
#  ('convene', 'shoppers'),
#  ('shoppers', 'stephanopoulos'),
#  ('stephanopoulos', 'bits'),
#  ('bits', 'cite'),
#  ('cite', 'williams'),
#  ('williams', 'shawl'),
#  ('shawl', 'kagan'),
#  ('kagan', 'proving'),
#  ('proving', 'meddling'),
#  ('meddling', 'southbound'),
#  ('southbound', 'ridiculous'),
#  ('ridiculous', 'supermajorities'),
#  ('supermajorities', 'fooled'),
#  ('fooled', 'representing'),
#  ('representing', 'bored'),
#  ('bored', 'iceberg'),
#  ('iceberg', 'speculative'),
#  ('speculative', 'rival'),
#  ('rival', 'folly'),
#  ('folly', 'banner'),
#  ('banner', 'siding'),
#  ('siding', 'future'),
#  ('future', 'cowen'),
#  ('cowen', 'nie'),
#  ('nie', 'bauer'),
#  ('bauer', 'simmering'),
#  ('simmering', 'drywall'),
#  ('drywall', 'russia'),
#  ('russia', 'prospect'),
#  ('prospect', 'mountain'),
#  ('mountain', 'addressing'),
#  ('addressing', 'illness'),
#  ('illness', 'san'),
#  ('san', 'nicer'),
#  ('nicer', 'fragmented'),
#  ('fragmented', 'veracity'),
#  ('veracity', 'franken'),
#  ('franken', 'turned'),
#  ('turned', 'argument'),
#  ('argument', 'notebook'),
#  ('notebook', 'sad'),
#  ('sad', 'prestigious'),
#  ('prestigious', 'spender'),
#  ('spender', 'buried'),
#  ('buried', 'lurking'),
#  ('lurking', 'wilsons'),
#  ('wilsons', 'allen'),
#  ('allen', 'regards'),
#  ('regards', 'saw'),
#  ('saw', 'politicos'),
#  ('politicos', 'sat'),
#  ('sat', 'wink'),
#  ('wink', 'unsuitable'),
#  ('unsuitable', 'warriors'),
#  ('warriors', 'employers'),
#  ('employers', 'downwards'),
#  ('downwards', 'aside'),
#  ('aside', 'instructed'),
#  ('instructed', 'note'),
#  ('note', 'graciously'),
#  ('graciously', 'intends'),
#  ('intends', 'jefferson'),
#  ('jefferson', 'massa'),
#  ('massa', 'take'),
#  ('take', 'roadside'),
#  ('roadside', 'wanting'),
#  ('wanting', 'mayer'),
#  ('mayer', 'atop'),
#  ('atop', 'towers'),
#  ('towers', 'progressiveaccountability'),
#  ('progressiveaccountability', 'handing'),
#  ('handing', 'murphy'),
#  ('murphy', 'maneuvering'),
#  ('maneuvering', 'decalogue'),
#  ('decalogue', 'opposite'),
#  ('opposite', 'syllable'),
#  ('syllable', 'discerning'),
#  ('discerning', 'knew'),
#  ('knew', 'downplayed'),
#  ('downplayed', 'suspects'),
#  ('suspects', 'airing'),
#  ('airing', 'remarks'),
#  ('remarks', 'knee'),
#  ('knee', 'knowingly'),
#  ('knowingly', 'pages'),
#  ('pages', 'armrest'),
#  ('armrest', 'lawn'),
#  ('lawn', 'ljungqvist'),
#  ('ljungqvist', 'badr'),
#  ('badr', 'energize'),
#  ('energize', 'bolsheviks'),
#  ('bolsheviks', 'average'),
#  ('average', 'phil'),
#  ('phil', 'drive'),
#  ('drive', 'defeating'),
#  ('defeating', 'ways'),
#  ('ways', 'bade'),
#  ('bade', 'backdrop'),
#  ('backdrop', 'refining'),
#  ('refining', 'hildebrand'),
#  ('hildebrand', 'redirected'),
#  ('redirected', 'salt'),
#  ('salt', 'addled'),
#  ('addled', 'laws'),
#  ('laws', 'walking'),
#  ('walking', 'misconduct'),
#  ('misconduct', 'surplus'),
#  ('surplus', 'restriction'),
#  ('restriction', 'morrissey'),
#  ('morrissey', 'definite'),
#  ('definite', 'imagines'),
#  ('imagines', 'mince'),
#  ('mince', 'merit'),
#  ('merit', 'sherrod'),
#  ('sherrod', 'bright'),
#  ('bright', 'inconsistent'),
#  ('inconsistent', 'dday'),
#  ('dday', 'scarce'),
#  ('scarce', 'aggressive'),
#  ('aggressive', 'imagined'),
#  ('imagined', 'dontgo'),
#  ('dontgo', 'slot'),
#  ('slot', 'belittled'),
#  ('belittled', 'slow'),
#  ('slow', 'strangled'),
#  ('strangled', 'interrogations'),
#  ('interrogations', 'nutshell'),
#  ('nutshell', 'aimlessly'),
#  ('aimlessly', 'debunk'),
#  ('debunk', 'tears'),
#  ('tears', 'slog'),
#  ('slog', 'equipped'),
#  ('equipped', 'outrage'),
#  ('outrage', 'caroline'),
#  ('caroline', 'steered'),
#  ('steered', 'robb'),
#  ('robb', 'congressional'),
#  ('congressional', 'carolina'),
#  ('carolina', 'graceless'),
#  ('graceless', 'misdemeanor'),
#  ('misdemeanor', 'ijaz'),
#  ('ijaz', 'assistant'),
#  ('assistant', 'condemning'),
#  ('condemning', 'gazette'),
#  ('gazette', 'tilting'),
#  ('tilting', 'harbors'),
#  ('harbors', 'recruiters'),
#  ('recruiters', 'simplistic'),
#  ('simplistic', 'sidestepping'),
#  ('sidestepping', 'infallible'),
#  ('infallible', 'outlet'),
#  ('outlet', 'awaiting'),
#  ('awaiting', 'prime'),
#  ('prime', 'diners'),
#  ('diners', 'resource'),
#  ('resource', 'keenly'),
#  ('keenly', 'artist'),
#  ('artist', 'celebrate'),
#  ('celebrate', 'borrow'),
#  ('borrow', 'absurdly'),
#  ('absurdly', 'worried'),
#  ('worried', 'tenured'),
#  ('tenured', 'priest'),
#  ('priest', 'roger'),
#  ('roger', 'toying'),
#  ('toying', 'bombs'),
#  ('bombs', 'worries'),
#  ('worries', 'disparage'),
#  ('disparage', 'testaments'),
#  ('testaments', 'vision'),
#  ('vision', 'corridors'),
#  ('corridors', 'fineman'),
#  ('fineman', 'hour'),
#  ('hour', 'espo'),
#  ('espo', 'cio'),
#  ('cio', 'keyboard'),
#  ('keyboard', 'appropriating'),
#  ('appropriating', 'impressions'),
#  ('impressions', 'surgery'),
#  ('surgery', 'fidelity'),
#  ('fidelity', 'refreshes'),
#  ('refreshes', 'planet'),
#  ('planet', 'inequalities'),
#  ('inequalities', 'compounds'),
#  ('compounds', 'ostensibly'),
#  ('ostensibly', 'jumped'),
#  ('jumped', 'heileman'),
#  ('heileman', 'sites'),
#  ('sites', 'goers'),
#  ('goers', 'vaccines'),
#  ('vaccines', 'sighting'),
#  ('sighting', 'bureau'),
#  ('bureau', 'nrsc'),
#  ('nrsc', 'moons'),
#  ('moons', 'affecting'),
#  ('affecting', 'exploration'),
#  ('exploration', 'enjoys'),
#  ('enjoys', 'baiting'),
#  ('baiting', 'screed'),
#  ('screed', 'jobs'),
#  ('jobs', 'odierno'),
#  ('odierno', 'screen'),
#  ('screen', 'planes'),
#  ('planes', 'supermarket'),
#  ('supermarket', 'manifesting'),
#  ('manifesting', 'adept'),
#  ('adept', 'concentrate'),
#  ('concentrate', 'awards'),
#  ('awards', 'menacing'),
#  ('menacing', 'spark'),
#  ('spark', 'policewomen'),
#  ('policewomen', 'uncharacteristically'),
#  ('uncharacteristically', 'undermine'),
#  ('undermine', 'reversing'),
#  ('reversing', 'many'),
#  ('many', 'millionaire'),
#  ('millionaire', 'flipped'),
#  ('flipped', 'besieging'),
#  ('besieging', 'loudly'),
#  ('loudly', 'workplace'),
#  ('workplace', 'rankings'),
#  ('rankings', 'semitic'),
#  ('semitic', 'expression'),
#  ('expression', 'mann'),
#  ('mann', 'desist'),
#  ('desist', 'handouts'),
#  ('handouts', 'bhutto'),
#  ('bhutto', 'cautioned'),
#  ('cautioned', 'mccain'),
#  ('mccain', 'furthered'),
#  ('furthered', 'homosexuality'),
#  ('homosexuality', 'anti'),
#  ('anti', 'bader'),
#  ('bader', 'comeback'),
#  ('comeback', 'ante'),
#  ('ante', 'virginians'),
#  ('virginians', 'considers'),
#  ('considers', 'boat'),
#  ('boat', 'math'),
#  ('math', 'caring'),
#  ('caring', 'surber'),
#  ('surber', 'testimonial'),
#  ('testimonial', 'teddy'),
#  ('teddy', 'stretch'),
#  ('stretch', 'mounting'),
#  ('mounting', 'airlines'),
#  ('airlines', 'concede'),
#  ('concede', 'breath'),
#  ('breath', 'defined'),
#  ('defined', 'collided'),
#  ('collided', 'combined'),
#  ('combined', 'motives'),
#  ('motives', 'caravans'),
#  ('caravans', 'reflective'),
#  ('reflective', 'crawford'),
#  ('crawford', 'diatribe'),
#  ('diatribe', 'wants'),
#  ('wants', 'enable'),
#  ('enable', 'lanes'),
#  ('lanes', 'gist'),
#  ('gist', 'starters'),
#  ('starters', 'ethical'),
#  ('ethical', 'deadliest'),
#  ('deadliest', 'thousand'),
#  ('thousand', 'formed'),
#  ('formed', 'quarantined'),
#  ('quarantined', 'centerpiece'),
#  ('centerpiece', 'pornography'),
#  ('pornography', 'rooftops'),
#  ('rooftops', 'americablog'),
#  ('americablog', 'incite'),
#  ('incite', 'offshore'),
#  ('offshore', 'abject'),
#  ('abject', 'psychotherapy'),
#  ('psychotherapy', 'alaire'),
#  ('alaire', 'former'),
#  ('former', 'queasy'),
#  ('queasy', 'consultant'),
#  ('consultant', 'defeatist'),
#  ('defeatist', 'polls'),
#  ('polls', 'prominence'),
#  ('prominence', 'consulted'),
#  ('consulted', 'hayes'),
#  ('hayes', 'unaccredited'),
#  ('unaccredited', 'cure'),
#  ('cure', 'policies'),
#  ('policies', 'blackhawk'),
#  ('blackhawk', 'newspaper'),
#  ('newspaper', 'situation'),
#  ('situation', 'constituency'),
#  ('constituency', 'passes'),
#  ('passes', 'penthouse'),
#  ('penthouse', 'perpetuate'),
#  ('perpetuate', 'croaked'),
#  ('croaked', 'shepard'),
#  ('shepard', 'transgressions'),
#  ('transgressions', 'park'),
#  ('park', 'twists'),
#  ('twists', 'dickishness'),
#  ('dickishness', 'engaged'),
#  ('engaged', 'hills'),
#  ('hills', 'dubious'),
#  ('dubious', 'blah'),
#  ('blah', 'regularity'),
#  ('regularity', 'lichter'),
#  ('lichter', 'hopefulness'),
#  ('hopefulness', 'engages'),
#  ('engages', 'technology'),
#  ('technology', 'fame'),
#  ('fame', 'expenditures'),
#  ('expenditures', 'missiles'),
#  ('missiles', 'verified'),
#  ('verified', 'obliterat'),
#  ('obliterat', 'hollinger'),
#  ('hollinger', 'threatens'),
#  ('threatens', 'legalistic'),
#  ('legalistic', 'perpetually'),
#  ('perpetually', 'helpfully'),
#  ('helpfully', 'surveillance'),
#  ('surveillance', 'princeton'),
#  ('princeton', 'wilhelm'),
#  ('wilhelm', 'underestimate'),
#  ('underestimate', 'weirauch'),
#  ('weirauch', 'motioned'),
#  ('motioned', 'prayers'),
#  ('prayers', 'inoffensive'),
#  ('inoffensive', 'homophobic'),
#  ('homophobic', 'breakdown'),
#  ('breakdown', 'nativism'),
#  ('nativism', 'putin'),
#  ('putin', 'edged'),
#  ('edged', 'newfound'),
#  ('newfound', 'sickness'),
#  ('sickness', 'boosted'),
#  ('boosted', 'defy'),
#  ('defy', 'cheers'),
#  ('cheers', 'harris'),
#  ('harris', 'barber'),
#  ('barber', 'advertisement'),
#  ('advertisement', 'intended'),
#  ('intended', 'culled'),
#  ('culled', 'disown'),
#  ('disown', 'devolved'),
#  ('devolved', 'renewable'),
#  ('renewable', 'booster'),
#  ('booster', 'lehrer'),
#  ('lehrer', 'costa'),
#  ('costa', 'rain'),
#  ('rain', 'tracking'),
#  ('tracking', 'colorblind'),
#  ('colorblind', 'undefined'),
#  ('undefined', 'utterance'),
#  ('utterance', 'coursework'),
#  ('coursework', 'milled'),
#  ('milled', 'meyerson'),
#  ('meyerson', 'costs'),
#  ('costs', 'trains'),
#  ('trains', 'quixotic'),
#  ('quixotic', 'ventually'),
#  ('ventually', 'persistently'),
#  ('persistently', 'effects'),
#  ('effects', 'gdp'),
#  ('gdp', 'summer'),
#  ('summer', 'morons'),
#  ('morons', 'rosenbaum'),
#  ('rosenbaum', 'exaggerating'),
#  ('exaggerating', 'rest'),
#  ('rest', 'safeguards'),
#  ('safeguards', 'recycled'),
#  ('recycled', 'fateful'),
#  ('fateful', 'invalid'),
#  ('invalid', 'summed'),
#  ('summed', 'chabot'),
#  ('chabot', 'weekly'),
#  ('weekly', 'roves'),
#  ('roves', 'occasional'),
#  ('occasional', 'loftier'),
#  ('loftier', 'townhall'),
#  ('townhall', 'grounded'),
#  ('grounded', 'kirk'),
#  ('kirk', 'briefings'),
#  ('briefings', 'fudge'),
#  ('fudge', 'eisenhower'),
#  ('eisenhower', 'involuntarily'),
#  ('involuntarily', 'khalaf'),
#  ('khalaf', 'overthrow'),
#  ('overthrow', 'prominently'),
# ...
#  ('phrased', 'embryo'),
#  ('embryo', 'exam'),
#  ('exam', 'plainly'),
#  ('plainly', 'heterosexuals'),
#  ('heterosexuals', 'echo'),
#  ('echo', 'listless'),
#  ('listless', 'proposing'),
#  ('proposing', 'probation'),
#  ('probation', 'taegan'),
#  ('taegan', 'outfits'),
#  ('outfits', 'salient'),
#  ('salient', 'publication'),
#  ('publication', 'unwashed'),
#  ('unwashed', 'unknown'),
#  ('unknown', 'myspace'),
#  ('myspace', 'rasmussen'),
#  ('rasmussen', 'priority'),
#  ('priority', 'stranahan'),
#  ('stranahan', 'stephan'),
#  ('stephan', 'appalachian'),
#  ('appalachian', 'boil'),
#  ('boil', 'misunderstood'),
#  ('misunderstood', 'tidbit'),
#  ('tidbit', 'academy'),
#  ('academy', 'reversed'),
#  ('reversed', 'celibate'),
#  ('celibate', 'squishy'),
#  ('squishy', 'slides'),
#  ('slides', 'reflecting'),
#  ('reflecting', 'tacitly'),
#  ('tacitly', 'july'),
#  ('july', 'institution'),
#  ('institution', 'dispelling'),
#  ('dispelling', 'hearings'),
#  ('hearings', 'liquid'),
#  ('liquid', 'kickback'),
#  ('kickback', 'objectionable'),
#  ('objectionable', 'isolation'),
#  ('isolation', 'limiting'),
#  ('limiting', 'patients'),
#  ('patients', 'basher'),
#  ('basher', 'appalachias'),
#  ('appalachias', 'clemson'),
#  ('clemson', 'laughingstock'),
#  ('laughingstock', 'outwardly'),
#  ('outwardly', 'clip'),
#  ('clip', 'cohen'),
#  ('cohen', 'teenagers'),
#  ('teenagers', 'blip'),
#  ('blip', 'alerted'),
#  ('alerted', 'nourish'),
#  ('nourish', 'imdb'),
#  ('imdb', 'sincerity'),
#  ('sincerity', 'faux'),
#  ('faux', 'induce'),
#  ('induce', 'filibustering'),
#  ('filibustering', 'academically'),
#  ('academically', 'linked'),
#  ('linked', 'spearhead'),
#  ('spearhead', 'catholic'),
#  ('catholic', 'afraid'),
#  ('afraid', 'angle'),
#  ('angle', 'triggered'),
#  ('triggered', 'propriety'),
#  ('propriety', 'oozing'),
#  ('oozing', 'agency'),
#  ('agency', 'boastful'),
#  ('boastful', 'copas'),
#  ('copas', 'polarization'),
#  ('polarization', 'unpacking'),
#  ('unpacking', 'aqim'),
#  ('aqim', 'bosnian'),
#  ('bosnian', 'alienating'),
#  ('alienating', 'infidels'),
#  ('infidels', 'divert'),
#  ('divert', 'trivia'),
#  ('trivia', 'pharmacist'),
#  ('pharmacist', 'divers'),
#  ('divers', 'lugar'),
#  ('lugar', 'bushie'),
#  ('bushie', 'combat'),
#  ('combat', 'centre'),
#  ('centre', 'collaboration'),
#  ('collaboration', 'pronouncement'),
#  ('pronouncement', 'accountants'),
#  ('accountants', 'evacuate'),
#  ('evacuate', 'invests'),
#  ('invests', 'alarmed'),
#  ('alarmed', 'statute'),
#  ('statute', 'deny'),
#  ('deny', 'refreshing'),
#  ('refreshing', 'surveyusa'),
#  ('surveyusa', 'askar'),
#  ('askar', 'brushed'),
#  ('brushed', 'neighboring'),
#  ('neighboring', 'archiving'),
#  ('archiving', 'physicists'),
#  ('physicists', 'mishaps'),
#  ('mishaps', 'dent'),
#  ('dent', 'looked'),
#  ('looked', 'idiosyncratic'),
#  ('idiosyncratic', 'fowler'),
#  ('fowler', 'xavier'),
#  ('xavier', 'inane'),
#  ('inane', 'gain'),
#  ('gain', 'smirked'),
#  ('smirked', 'buchenwald'),
#  ('buchenwald', 'latinos'),
#  ('latinos', 'brenda'),
#  ('brenda', 'tem'),
#  ('tem', 'chances'),
#  ('chances', 'please'),
#  ('please', 'agreed'),
#  ('agreed', 'kaput'),
#  ('kaput', 'artfully'),
#  ('artfully', 'superimposes'),
#  ('superimposes', 'purely'),
#  ('purely', 'planning'),
#  ('planning', 'democrats'),
#  ('democrats', 'quesiton'),
#  ('quesiton', 'utter'),
#  ('utter', 'fear'),
#  ('fear', 'darkest'),
#  ('darkest', 'feat'),
#  ('feat', 'pleased'),
#  ('pleased', 'ha'),
#  ('ha', 'exacerbating'),
#  ('exacerbating', 'leanings'),
#  ('leanings', 'hobnobbing'),
#  ('hobnobbing', 'goldwater'),
#  ('goldwater', 'operational'),
#  ('operational', 'politicized'),
#  ('politicized', 'candidates'),
#  ('candidates', 'constituents'),
#  ('constituents', 'piano'),
#  ('piano', 'local'),
#  ('local', 'okla'),
#  ('okla', 'spun'),
#  ('spun', 'prosecute'),
#  ('prosecute', 'sued'),
#  ('sued', 'fabulous'),
#  ('fabulous', 'watching'),
#  ('watching', 'plaintiff'),
#  ('plaintiff', 'mainly'),
#  ('mainly', 'massacre'),
#  ('massacre', 'sponsors'),
#  ('sponsors', 'rockford'),
#  ('rockford', 'ones'),
#  ('ones', 'words'),
#  ('words', 'burglary'),
#  ('burglary', 'penetrate'),
#  ('penetrate', 'spur'),
#  ('spur', 'rendition'),
#  ('rendition', 'queried'),
#  ('queried', 'fangs'),
#  ('fangs', 'homosexuals'),
#  ('homosexuals', 'ended'),
#  ('ended', 'deceiver'),
#  ('deceiver', 'descendant'),
#  ('descendant', 'married'),
#  ('married', 'maria'),
#  ('maria', 'kneel'),
#  ('kneel', 'swear'),
#  ('swear', 'cleavage'),
#  ('cleavage', 'reno'),
#  ('reno', 'generations'),
#  ('generations', 'view'),
#  ('view', 'unison'),
#  ('unison', 'predictive'),
#  ('predictive', 'requirement'),
#  ('requirement', 'inventive'),
#  ('inventive', 'rookie'),
#  ('rookie', 'humiliation'),
#  ('humiliation', 'expel'),
#  ('expel', 'awyers'),
#  ('awyers', 'merits'),
#  ('merits', 'paulson'),
#  ('paulson', 'unfairly'),
#  ('unfairly', 'confrontational'),
#  ('confrontational', 'responses'),
#  ('responses', 'closer'),
#  ('closer', 'closes'),
#  ('closes', 'cole'),
#  ('cole', 'televised'),
#  ('televised', 'closet'),
#  ('closet', 'windfall'),
#  ('windfall', 'arguably'),
#  ('arguably', 'millionth'),
#  ('millionth', 'broach'),
#  ('broach', 'favor'),
#  ('favor', 'projecting'),
#  ('projecting', 'identification'),
#  ('identification', 'closed'),
#  ('closed', 'dividends'),
#  ('dividends', 'crude'),
#  ('crude', 'stories'),
#  ('stories', 'torpedo'),
#  ('torpedo', 'frustrated'),
#  ('frustrated', 'bought'),
#  ('bought', 'publishers'),
#  ('publishers', 'weighing'),
#  ('weighing', 'ability'),
#  ('ability', 'opening'),
#  ('opening', 'joy'),
#  ('joy', 'rescuers'),
#  ('rescuers', 'gunships'),
#  ('gunships', 'tending'),
#  ('tending', 'embarrassment'),
#  ('embarrassment', 'job'),
#  ('job', 'takeover'),
#  ('takeover', 'joe'),
#  ('joe', 'swift'),
#  ('swift', 'jon'),
#  ('jon', 'barrett'),
#  ('barrett', 'karzai'),
#  ('karzai', 'commands'),
#  ('commands', 'legendary'),
#  ('legendary', 'evolutions'),
#  ('evolutions', 'parrot'),
#  ('parrot', 'respondents'),
#  ('respondents', 'wnbc'),
#  ('wnbc', 'april'),
#  ('april', 'unfocused'),
#  ('unfocused', 'grain'),
#  ('grain', 'urging'),
#  ('urging', 'grail'),
#  ('grail', 'tactical'),
#  ('tactical', 'acquiescing'),
#  ('acquiescing', 'safely'),
#  ('safely', 'traction'),
#  ('traction', 'withdraws'),
#  ('withdraws', 'unclear'),
#  ('unclear', 'disenfranchised'),
#  ('disenfranchised', 'wall'),
#  ('wall', 'shoving'),
#  ('shoving', 'narrower'),
#  ('narrower', 'environments'),
#  ('environments', 'walk'),
#  ('walk', 'subscribe'),
#  ('subscribe', 'thinkprogress'),
#  ('thinkprogress', 'table'),
#  ('table', 'narrowed'),
#  ('narrowed', 'flourish'),
#  ('flourish', 'withdrawn'),
#  ('withdrawn', 'walz'),
#  ('walz', 'amigo'),
#  ('amigo', 'disarming'),
#  ('disarming', 'fountains'),
#  ('fountains', 'hindu'),
#  ('hindu', 'hunters'),
#  ('hunters', 'trademark'),
#  ('trademark', 'arvada'),
#  ('arvada', 'responds'),
#  ('responds', 'literal'),
#  ('literal', 'sidesteps'),
#  ('sidesteps', 'agreements'),
#  ('agreements', 'olson'),
#  ('olson', 'semaphore'),
#  ('semaphore', 'bewildering'),
#  ('bewildering', 'cheek'),
#  ('cheek', 'remedies'),
#  ('remedies', 'legislature'),
#  ('legislature', 'mike'),
#  ('mike', 'cleese'),
#  ('cleese', 'harshest'),
#  ('harshest', 'sufficient'),
#  ('sufficient', 'nominations'),
#  ('nominations', 'scrutiny'),
#  ('scrutiny', 'overture'),
#  ('overture', 'hmm'),
#  ('hmm', 'ensuring'),
#  ('ensuring', 'exploding'),
#  ('exploding', 'remedied'),
#  ('remedied', 'improved'),
#  ('improved', 'overturn'),
#  ('overturn', 'present'),
#  ('present', 'erin'),
#  ('erin', 'abandoned'),
#  ('abandoned', 'unlike'),
#  ('unlike', 'wilt'),
#  ('wilt', 'align'),
#  ('align', 'restaurant'),
#  ('restaurant', 'feingold'),
#  ('feingold', 'irate'),
#  ('irate', 'choices'),
#  ('choices', 'stunning'),
#  ('stunning', 'wild'),
#  ('wild', 'madeleine'),
#  ('madeleine', 'cutter'),
#  ('cutter', 'layer'),
#  ('layer', 'offending'),
#  ('offending', 'henkel'),
#  ('henkel', 'refs'),
#  ('refs', 'thus'),
#  ('thus', 'encouragement'),
#  ('encouragement', 'pews'),
#  ('pews', 'blacker'),
#  ('blacker', 'audiences'),
#  ('audiences', 'avi'),
#  ('avi', 'dual'),
#  ('dual', 'thug'),
#  ('thug', 'disinterred'),
#  ('disinterred', 'whore'),
#  ('whore', 'perhaps'),
#  ('perhaps', 'privileges'),
#  ('privileges', 'headlight'),
#  ('headlight', 'maddening'),
#  ('maddening', 'cross'),
#  ('cross', 'mcclellan'),
#  ('mcclellan', 'eric'),
#  ('eric', 'member'),
#  ('member', 'propensity'),
#  ('propensity', 'unity'),
#  ('unity', 'merciful'),
#  ('merciful', 'geographical'),
#  ('geographical', 'largest'),
#  ('largest', 'units'),
#  ('units', 'gets'),
#  ('gets', 'difficult'),
#  ('difficult', 'cellphones'),
#  ('cellphones', 'elbows'),
#  ('elbows', 'coached'),
#  ('coached', 'promo'),
#  ('promo', 'disagree'),
#  ('disagree', 'conspired'),
#  ('conspired', 'pepperdine'),
#  ('pepperdine', 'subtexts'),
#  ('subtexts', 'student'),
#  ('student', 'lopsided'),
#  ('lopsided', 'whale'),
#  ('whale', 'doocy'),
#  ('doocy', 'lobby'),
#  ('lobby', 'warming'),
#  ('warming', 'disclosures'),
#  ('disclosures', 'scaling'),
#  ('scaling', 'antsy'),
#  ('antsy', 'appropriated'),
#  ('appropriated', 'valerie'),
#  ('valerie', 'whole'),
#  ('whole', 'unimpeachable'),
#  ('unimpeachable', 'arrival'),
#  ('arrival', 'banging'),
#  ('banging', 'fighting'),
#  ('fighting', 'catastrophically'),
#  ('catastrophically', 'english'),
#  ('english', 'tails'),
#  ('tails', 'breaker'),
#  ('breaker', 'contenders'),
#  ('contenders', 'telegraphing'),
#  ('telegraphing', 'boos'),
#  ('boos', 'routinely'),
#  ('routinely', 'cried'),
#  ('cried', 'heavily'),
#  ('heavily', 'percent'),
#  ('percent', 'half'),
#  ('half', 'obtain'),
#  ('obtain', 'recap'),
#  ('recap', 'batteries'),
#  ('batteries', 'recollection'),
#  ('recollection', 'fishing'),
#  ('fishing', 'rocked'),
#  ('rocked', 'decriptions'),
#  ('decriptions', 'miniscule'),
#  ('miniscule', 'untested'),
#  ('untested', 'muzzled'),
#  ('muzzled', 'backroom'),
#  ('backroom', 'temerity'),
#  ('temerity', 'fernholz'),
#  ('fernholz', 'rapid'),
#  ('rapid', 'supply'),
#  ('supply', 'smith'),
#  ('smith', 'capabilities'),
#  ('capabilities', 'discuss'),
#  ('discuss', 'googling'),
#  ('googling', 'adoption'),
#  ('adoption', 'halo'),
#  ('halo', 'sparking'),
#  ('sparking', 'rescind'),
#  ('rescind', 'loan'),
#  ('loan', 'identical'),
#  ('identical', 'wont'),
#  ('wont', 'frieze'),
#  ('frieze', 'sick'),
#  ('sick', 'provisions'),
#  ('provisions', 'meeuwsen'),
#  ('meeuwsen', 'execute'),
#  ('execute', 'allegiance'),
#  ('allegiance', 'interrogation'),
#  ('interrogation', 'know'),
#  ('know', 'facial'),
#  ('facial', 'rajasthan'),
#  ('rajasthan', 'press'),
#  ('press', 'cpac'),
#  ('cpac', 'palfrey'),
#  ('palfrey', 'coincidence'),
#  ('coincidence', 'racists'),
#  ('racists', 'helpful'),
#  ('helpful', 'kuwait'),
#  ('kuwait', 'panicking'),
#  ('panicking', 'safest'),
#  ('safest', 'perpetual'),
#  ('perpetual', 'levy'),
#  ('levy', 'loser'),
#  ('loser', 'loses'),
#  ('loses', 'taxpayers'),
#  ('taxpayers', 'galloway'),
#  ('galloway', 'backlash'),
#  ('backlash', 'dietary'),
#  ('dietary', 'hosts'),
#  ('hosts', 'james'),
#  ('james', 'subprime'),
#  ('subprime', 'indymac'),
#  ('indymac', 'wonders'),
#  ('wonders', 'parity'),
#  ('parity', 'exceed'),
#  ('exceed', 'shabby'),
#  ('shabby', 'smoothly'),
#  ('smoothly', 'hollen'),
#  ('hollen', 'scared'),
#  ('scared', 'scottish'),
#  ('scottish', 'heilemann'),
#  ('heilemann', 'searching'),
#  ('searching', 'socialists'),
#  ('socialists', 'platforms'),
#  ('platforms', 'fingers'),
#  ('fingers', 'growth'),
#  ('growth', 'manning'),
#  ('manning', 'openness'),
#  ('openness', 'racking'),
#  ('racking', 'empire'),
#  ('empire', 'employment'),
#  ('employment', 'scares'),
#  ('scares', 'proprietorships'),
#  ('proprietorships', 'cutters'),
#  ('cutters', 'suiciders'),
#  ('suiciders', 'leaf'),
#  ('leaf', 'lead'),
#  ('lead', 'leak'),
#  ('leak', 'breakthroughs'),
#  ('breakthroughs', 'lean'),
#  ('lean', 'detergent'),
#  ('detergent', 'leap'),
#  ('leap', 'distractions'),
#  ('distractions', 'bosses'),
#  ('bosses', 'glacial'),
#  ('glacial', 'worsen'),
#  ('worsen', 'murdoch'),
#  ('murdoch', 'murdock'),
#  ('murdock', 'ripped'),
#  ('ripped', 'obey'),
#  ('obey', 'apostolic'),
#  ('apostolic', 'dangling'),
#  ('dangling', 'mitt'),
#  ('mitt', 'handedly'),
#  ('handedly', 'dismissals'),
#  ('dismissals', 'wesley'),
#  ('wesley', 'murdered'),
#  ('murdered', 'spokes'),
#  ('spokes', 'jung'),
#  ('jung', 'importation'),
#  ('importation', 'analyses'),
#  ('analyses', 'insults'),
#  ('insults', 'slug'),
#  ('slug', 'perspectives'),
#  ('perspectives', 'screeching'),
#  ('screeching', 'rare'),
#  ('rare', 'carried'),
#  ('carried', 'extension'),
#  ('extension', 'getting'),
#  ('getting', 'column'),
#  ('column', 'abstinence'),
#  ('abstinence', 'sectarian'),
#  ('sectarian', 'urged'),
#  ('urged', 'surge'),
#  ('surge', 'carries'),
#  ('carries', 'carrier'),
#  ('carrier', 'loebsack'),
#  ('loebsack', 'sweat'),
#  ('sweat', 'stomped'),
#  ('stomped', 'backstage'),
#  ('backstage', 'emperor'),
#  ('emperor', 'heroics'),
#  ('heroics', 'outstripped'),
#  ('outstripped', 'outset'),
#  ('outset', 'kinda'),
#  ('kinda', 'portrait'),
#  ('portrait', 'owe'),
#  ('owe', 'travelers'),
#  ('travelers', 'warrants'),
#  ('warrants', 'emotive'),
#  ('emotive', 'talladega'),
#  ('talladega', 'fundraiser'),
#  ('fundraiser', 'weather'),
#  ('weather', 'promise'),
#  ('promise', 'brush'),
#  ('brush', 'registration'),
#  ('registration', 'yanked'),
#  ('yanked', 'brilliantly'),
#  ('brilliantly', 'convicted'),
#  ('convicted', 'fawning'),
#  ('fawning', 'van'),
#  ('van', 'platoon'),
#  ('platoon', 'unpatriotic'),
#  ('unpatriotic', 'transfer'),
#  ('transfer', 'indictments'),
#  ('indictments', 'kidding'),
#  ('kidding', 'continental'),
#  ('continental', 'intention'),
#  ('intention', 'posters'),
#  ('posters', 'thimerosal'),
#  ('thimerosal', 'extravagant'),
#  ('extravagant', 'upwards'),
#  ('upwards', 'corley'),
#  ('corley', 'punditocracy'),
#  ('punditocracy', 'knesset'),
#  ('knesset', 'mailer'),
#  ('mailer', 'appointing'),
#  ('appointing', 'shank'),
#  ('shank', 'funds'),
#  ('funds', 'bitches'),
#  ('bitches', 'volume'),
#  ('volume', 'tasked'),
#  ('tasked', 'contradictory'),
#  ('contradictory', 'liquor'),
#  ('liquor', 'automated'),
#  ('automated', 'wage'),
#  ('wage', 'teaming'),
#  ('teaming', 'squeeze'),
#  ('squeeze', 'memogate'),
#  ('memogate', 'bradley'),
#  ('bradley', 'made'),
#  ('made', 'tactics'),
#  ('tactics', 'temp'),
#  ('temp', 'instructive'),
#  ('instructive', 'whether'),
#  ('whether', 'protesting'),
#  ('protesting', 'embolden'),
#  ('embolden', 'insipid'),
#  ('insipid', 'distract'),
#  ('distract', 'retool'),
#  ('retool', 'mattering'),
#  ('mattering', 'record'),
#  ('record', 'persian'),
#  ('persian', 'garish'),
#  ('garish', 'ruling'),
#  ('ruling', 'arne'),
#  ('arne', 'cake'),
#  ('cake', 'demonstrate'),
#  ('demonstrate', 'faggot'),
#  ('faggot', 'sympathizing'),
#  ('sympathizing', 'lakeland'),
#  ('lakeland', 'stirring'),
#  ('stirring', 'unfolding'),
#  ('unfolding', 'heralding'),
#  ('heralding', 'horrific'),
#  ('horrific', 'intimidating'),
#  ('intimidating', 'meaningless'),
#  ('meaningless', 'persistent'),
#  ('persistent', 'spanks'),
#  ('spanks', 'schmoe'),
#  ('schmoe', 'goodness'),
#  ('goodness', 'raced'),
#  ('raced', 'rightwing'),
#  ('rightwing', 'trailing'),
#  ('trailing', 'naming'),
#  ('naming', 'penumbras'),
#  ('penumbras', 'dithering'),
#  ('dithering', 'diplomat'),
#  ('diplomat', 'courant'),
#  ('courant', 'incredible'),
#  ('incredible', 'demonize'),
#  ('demonize', 'roark'),
#  ('roark', 'memeorandum'),
#  ('memeorandum', 'pickings'),
#  ('pickings', 'illinois'),
#  ('illinois', 'smears'),
#  ('smears', 'book'),
#  ('book', 'boom'),
#  ('boom', 'branch'),
#  ('branch', 'donohue'),
#  ('donohue', 'unabashedly'),
#  ('unabashedly', 'incredibly'),
#  ('incredibly', 'honorary'),
#  ('honorary', 'asterisk'),
#  ('asterisk', 'conclusion'),
#  ('conclusion', 'lance'),
#  ('lance', 'illegally'),
#  ('illegally', 'chavez'),
#  ('chavez', 'kinds'),
#  ('kinds', 'volumes'),
#  ('volumes', 'shredded'),
#  ('shredded', 'bandied'),
#  ('bandied', 'june'),
#  ('june', 'inherently'),
#  ('inherently', 'risked'),
#  ('risked', 'margaret'),
#  ('margaret', 'medications'),
#  ('medications', 'ceos'),
#  ('ceos', 'pertaining'),
#  ('pertaining', 'gap'),
#  ('gap', 'tan'),
#  ('tan', 'cliff'),
#  ('cliff', 'delauro'),
#  ('delauro', 'reticence'),
#  ('reticence', 'ranks'),
#  ('ranks', 'expands'),
#  ('expands', 'dearly'),
#  ('dearly', 'infuriated'),
#  ('infuriated', 'intentionally'),
#  ('intentionally', 'profit'),
#  ('profit', 'inexcusable'),
#  ('inexcusable', 'firestorm'),
#  ('firestorm', 'ideological'),
#  ('ideological', 'richardson'),
#  ('richardson', 'rocchios'),
#  ('rocchios', 'mobutu'),
#  ('mobutu', 'furthermore')]
